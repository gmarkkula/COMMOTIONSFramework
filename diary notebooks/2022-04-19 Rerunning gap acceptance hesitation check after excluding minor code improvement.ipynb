# %% [markdown]
# # 2022-04-19 Rerunning gap acceptance hesitation check after excluding minor code improvement
#
# Results below are for commit: ###
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# As noted in the 2021-01-17b diary notes, in most of the cases where the pedestrian gap acceptance hesitation check (`do_7_check_hesitation.py`) rejected parameterisations for non-`oAN` models, this was because that parameterisation had generated at least one simulation where the pedestrian did not enter the conflict space, yielding a NaN. I have now rerun this test, after adding code to exclude such simulations.
#
# Results pasted below (scroll to end for summary). The outcome is that now almost every single parameterisation for the non-`oAN` models is confirmed. The only exception is one parameterisation for `oVAoEAoSNvoPF`, which seems to quite possibly also be hesitating / slowing down, but not enough for the 95% confidence intervals to be non-overlapping in this test.
#
#
#     Starting pool of workers...
#     Model oVAoAN; ('sigma_V',):
#             {'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.065 m/s; CI: [0.999, 1.130] m/s
#                     TTCA = 8 s: Av: 1.171 m/s; CI: [1.114, 1.227] m/s
#     Model oVAoEAoAN; ('T', 'DeltaV_th_rel', 'sigma_V'):
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0027825594022071257, 'sigma_V': 0.004641588833612777}...
#                     TTCA = -3 s: Av: 1.287 m/s; CI: [1.260, 1.315] m/s
#                     TTCA = 8 s: Av: 1.289 m/s; CI: [1.249, 1.328] m/s
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.007742636826811269, 'sigma_V': 0.004641588833612777}...
#                     TTCA = -3 s: Av: 1.287 m/s; CI: [1.248, 1.326] m/s
#                     TTCA = 8 s: Av: 1.276 m/s; CI: [1.238, 1.314] m/s
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.01}...
#                     TTCA = -3 s: Av: 1.096 m/s; CI: [1.010, 1.181] m/s
#                     TTCA = 8 s: Av: 1.190 m/s; CI: [1.130, 1.250] m/s
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.01}...
#                     TTCA = -3 s: Av: 1.213 m/s; CI: [1.168, 1.257] m/s
#                     TTCA = 8 s: Av: 1.238 m/s; CI: [1.197, 1.279] m/s
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.01}...
#                     TTCA = -3 s: Av: 1.161 m/s; CI: [1.096, 1.227] m/s
#                     TTCA = 8 s: Av: 1.202 m/s; CI: [1.143, 1.261] m/s
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.01}...
#                     TTCA = -3 s: Av: 1.224 m/s; CI: [1.148, 1.301] m/s
#                     TTCA = 8 s: Av: 1.208 m/s; CI: [1.139, 1.277] m/s
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.01}...
#                     TTCA = -3 s: Av: 1.151 m/s; CI: [1.071, 1.230] m/s
#                     TTCA = 8 s: Av: 1.198 m/s; CI: [1.133, 1.263] m/s
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.004641588833612777, 'sigma_V': 0.01}...
#                     TTCA = -3 s: Av: 1.181 m/s; CI: [1.114, 1.248] m/s
#                     TTCA = 8 s: Av: 1.251 m/s; CI: [1.193, 1.308] m/s
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.004641588833612777, 'sigma_V': 0.01}...
#                     TTCA = -3 s: Av: 1.181 m/s; CI: [1.087, 1.276] m/s
#                     TTCA = 8 s: Av: 1.228 m/s; CI: [1.151, 1.305] m/s
#             {'T': 0.5, 'DeltaV_th_rel': 0.004641588833612777, 'sigma_V': 0.01}...
#                     TTCA = -3 s: Av: 1.105 m/s; CI: [1.028, 1.183] m/s
#                     TTCA = 8 s: Av: 1.254 m/s; CI: [1.163, 1.344] m/s
#             {'T': 0.5, 'DeltaV_th_rel': 0.007742636826811269, 'sigma_V': 0.01}...
#                     TTCA = -3 s: Av: 1.299 m/s; CI: [1.197, 1.401] m/s
#                     TTCA = 8 s: Av: 1.361 m/s; CI: [1.261, 1.460] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.216 m/s; CI: [1.154, 1.278] m/s
#                     TTCA = 8 s: Av: 1.196 m/s; CI: [1.145, 1.247] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.141 m/s; CI: [1.078, 1.205] m/s
#                     TTCA = 8 s: Av: 1.162 m/s; CI: [1.105, 1.219] m/s
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.073 m/s; CI: [0.971, 1.175] m/s
#                     TTCA = 8 s: Av: 1.118 m/s; CI: [1.053, 1.184] m/s
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.160 m/s; CI: [1.072, 1.249] m/s
#                     TTCA = 8 s: Av: 1.184 m/s; CI: [1.105, 1.264] m/s
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.079 m/s; CI: [0.982, 1.175] m/s
#                     TTCA = 8 s: Av: 1.233 m/s; CI: [1.127, 1.338] m/s
#             {'T': 0.5, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.282 m/s; CI: [1.157, 1.406] m/s
#                     TTCA = 8 s: Av: 1.399 m/s; CI: [1.237, 1.561] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.200 m/s; CI: [1.136, 1.263] m/s
#                     TTCA = 8 s: Av: 1.197 m/s; CI: [1.146, 1.248] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.111 m/s; CI: [1.036, 1.185] m/s
#                     TTCA = 8 s: Av: 1.176 m/s; CI: [1.125, 1.228] m/s
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.099 m/s; CI: [1.023, 1.176] m/s
#                     TTCA = 8 s: Av: 1.177 m/s; CI: [1.117, 1.237] m/s
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.146 m/s; CI: [1.072, 1.220] m/s
#                     TTCA = 8 s: Av: 1.171 m/s; CI: [1.106, 1.236] m/s
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.100 m/s; CI: [1.008, 1.192] m/s
#                     TTCA = 8 s: Av: 1.204 m/s; CI: [1.128, 1.281] m/s
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.129 m/s; CI: [1.035, 1.222] m/s
#                     TTCA = 8 s: Av: 1.088 m/s; CI: [1.035, 1.142] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0027825594022071257, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.201 m/s; CI: [1.138, 1.263] m/s
#                     TTCA = 8 s: Av: 1.162 m/s; CI: [1.115, 1.210] m/s
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0027825594022071257, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.122 m/s; CI: [1.047, 1.197] m/s
#                     TTCA = 8 s: Av: 1.113 m/s; CI: [1.059, 1.167] m/s
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0027825594022071257, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.099 m/s; CI: [1.009, 1.190] m/s
#                     TTCA = 8 s: Av: 1.214 m/s; CI: [1.115, 1.313] m/s
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0027825594022071257, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.109 m/s; CI: [1.001, 1.217] m/s
#                     TTCA = 8 s: Av: 1.214 m/s; CI: [1.103, 1.325] m/s
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.004641588833612777, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.206 m/s; CI: [1.086, 1.326] m/s
#                     TTCA = 8 s: Av: 1.282 m/s; CI: [1.175, 1.390] m/s
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.007742636826811269, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.125 m/s; CI: [1.037, 1.213] m/s
#                     TTCA = 8 s: Av: 1.152 m/s; CI: [1.088, 1.216] m/s
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.007742636826811269, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.192 m/s; CI: [1.093, 1.290] m/s
#                     TTCA = 8 s: Av: 1.201 m/s; CI: [1.121, 1.280] m/s
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.007742636826811269, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.180 m/s; CI: [1.086, 1.273] m/s
#                     TTCA = 8 s: Av: 1.175 m/s; CI: [1.092, 1.259] m/s
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.01291549665014884, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.255 m/s; CI: [1.186, 1.324] m/s
#                     TTCA = 8 s: Av: 1.204 m/s; CI: [1.139, 1.269] m/s
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.01291549665014884, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.168 m/s; CI: [1.072, 1.265] m/s
#                     TTCA = 8 s: Av: 1.166 m/s; CI: [1.081, 1.251] m/s
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.01291549665014884, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.241 m/s; CI: [1.108, 1.375] m/s
#                     TTCA = 8 s: Av: 1.224 m/s; CI: [1.097, 1.351] m/s
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.021544346900318832, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.204 m/s; CI: [1.110, 1.297] m/s
#                     TTCA = 8 s: Av: 1.260 m/s; CI: [1.172, 1.349] m/s
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.03593813663804626, 'sigma_V': 0.021544346900318832}...
#                     TTCA = -3 s: Av: 1.274 m/s; CI: [1.189, 1.358] m/s
#                     TTCA = 8 s: Av: 1.259 m/s; CI: [1.183, 1.334] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.080 m/s; CI: [0.994, 1.167] m/s
#                     TTCA = 8 s: Av: 1.132 m/s; CI: [1.070, 1.195] m/s
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.122 m/s; CI: [1.018, 1.227] m/s
#                     TTCA = 8 s: Av: 1.212 m/s; CI: [1.109, 1.315] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.115 m/s; CI: [1.038, 1.193] m/s
#                     TTCA = 8 s: Av: 1.145 m/s; CI: [1.078, 1.212] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.152 m/s; CI: [1.066, 1.239] m/s
#                     TTCA = 8 s: Av: 1.177 m/s; CI: [1.096, 1.258] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.0027825594022071257, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.129 m/s; CI: [1.044, 1.215] m/s
#                     TTCA = 8 s: Av: 1.181 m/s; CI: [1.097, 1.266] m/s
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0027825594022071257, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.254 m/s; CI: [1.139, 1.368] m/s
#                     TTCA = 8 s: Av: 1.201 m/s; CI: [1.115, 1.286] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.004641588833612777, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.066 m/s; CI: [0.988, 1.144] m/s
#                     TTCA = 8 s: Av: 1.125 m/s; CI: [1.044, 1.205] m/s
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.004641588833612777, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.445 m/s; CI: [1.294, 1.596] m/s
#                     TTCA = 8 s: Av: 1.345 m/s; CI: [1.222, 1.467] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.01291549665014884, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.082 m/s; CI: [1.004, 1.161] m/s
#                     TTCA = 8 s: Av: 1.214 m/s; CI: [1.147, 1.280] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.01291549665014884, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.138 m/s; CI: [1.039, 1.237] m/s
#                     TTCA = 8 s: Av: 1.235 m/s; CI: [1.141, 1.328] m/s
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.01291549665014884, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.153 m/s; CI: [1.054, 1.253] m/s
#                     TTCA = 8 s: Av: 1.181 m/s; CI: [1.099, 1.263] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.021544346900318832, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.152 m/s; CI: [1.036, 1.267] m/s
#                     TTCA = 8 s: Av: 1.200 m/s; CI: [1.116, 1.283] m/s
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.021544346900318832, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.202 m/s; CI: [1.082, 1.321] m/s
#                     TTCA = 8 s: Av: 1.230 m/s; CI: [1.132, 1.328] m/s
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.021544346900318832, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.337 m/s; CI: [1.208, 1.466] m/s
#                     TTCA = 8 s: Av: 1.314 m/s; CI: [1.201, 1.428] m/s
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.03593813663804626, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.231 m/s; CI: [1.131, 1.330] m/s
#                     TTCA = 8 s: Av: 1.309 m/s; CI: [1.218, 1.399] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.05994842503189409, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.219 m/s; CI: [1.119, 1.320] m/s
#                     TTCA = 8 s: Av: 1.257 m/s; CI: [1.169, 1.346] m/s
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.05994842503189409, 'sigma_V': 0.046415888336127774}...
#                     TTCA = -3 s: Av: 1.292 m/s; CI: [1.194, 1.390] m/s
#                     TTCA = 8 s: Av: 1.239 m/s; CI: [1.141, 1.336] m/s
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.690 m/s; CI: [1.467, 1.913] m/s
#                     TTCA = 8 s: Av: 1.683 m/s; CI: [1.458, 1.909] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.182 m/s; CI: [1.049, 1.315] m/s
#                     TTCA = 8 s: Av: 1.216 m/s; CI: [1.119, 1.314] m/s
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0016681005372000592, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.600 m/s; CI: [1.427, 1.774] m/s
#                     TTCA = 8 s: Av: 1.510 m/s; CI: [1.332, 1.689] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.0027825594022071257, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.211 m/s; CI: [1.107, 1.316] m/s
#                     TTCA = 8 s: Av: 1.307 m/s; CI: [1.187, 1.427] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0027825594022071257, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.315 m/s; CI: [1.180, 1.449] m/s
#                     TTCA = 8 s: Av: 1.373 m/s; CI: [1.243, 1.502] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.004641588833612777, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.123 m/s; CI: [1.026, 1.219] m/s
#                     TTCA = 8 s: Av: 1.286 m/s; CI: [1.183, 1.389] m/s
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.004641588833612777, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.325 m/s; CI: [1.191, 1.460] m/s
#                     TTCA = 8 s: Av: 1.368 m/s; CI: [1.223, 1.513] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.01291549665014884, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.232 m/s; CI: [1.107, 1.356] m/s
#                     TTCA = 8 s: Av: 1.285 m/s; CI: [1.183, 1.387] m/s
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.01291549665014884, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.399 m/s; CI: [1.217, 1.582] m/s
#                     TTCA = 8 s: Av: 1.636 m/s; CI: [1.481, 1.792] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.021544346900318832, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.212 m/s; CI: [1.076, 1.348] m/s
#                     TTCA = 8 s: Av: 1.273 m/s; CI: [1.151, 1.395] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.03593813663804626, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.324 m/s; CI: [1.184, 1.465] m/s
#                     TTCA = 8 s: Av: 1.349 m/s; CI: [1.245, 1.452] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.05994842503189409, 'sigma_V': 0.1}...
#                     TTCA = -3 s: Av: 1.244 m/s; CI: [1.121, 1.367] m/s
#                     TTCA = 8 s: Av: 1.270 m/s; CI: [1.169, 1.371] m/s
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0027825594022071257, 'sigma_V': 0.21544346900318823}...
#                     TTCA = -3 s: Av: 1.766 m/s; CI: [1.558, 1.974] m/s
#                     TTCA = 8 s: Av: 2.022 m/s; CI: [1.769, 2.275] m/s
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.007742636826811269, 'sigma_V': 0.21544346900318823}...
#                     TTCA = -3 s: Av: 1.522 m/s; CI: [1.344, 1.699] m/s
#                     TTCA = 8 s: Av: 1.585 m/s; CI: [1.405, 1.764] m/s
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.021544346900318832, 'sigma_V': 0.21544346900318823}...
#                     TTCA = -3 s: Av: 1.750 m/s; CI: [1.548, 1.951] m/s
#                     TTCA = 8 s: Av: 1.689 m/s; CI: [1.479, 1.899] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.03593813663804626, 'sigma_V': 0.21544346900318823}...
#                     TTCA = -3 s: Av: 1.530 m/s; CI: [1.365, 1.696] m/s
#                     TTCA = 8 s: Av: 1.506 m/s; CI: [1.339, 1.674] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.1, 'sigma_V': 0.46415888336127775}...
#                     TTCA = -3 s: Av: 1.784 m/s; CI: [1.585, 1.984] m/s
#                     TTCA = 8 s: Av: 1.776 m/s; CI: [1.584, 1.968] m/s
#     Model oVAoEAoSNc; ('T', 'DeltaV_th_rel', 'tau_d'):
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.004641588833612777, 'tau_d': 499.99999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.142 m/s; CI: [1.041, 1.243] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.004641588833612777, 'tau_d': 499.99999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.855 m/s; CI: [0.728, 0.983] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.004641588833612777, 'tau_d': 499.99999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.758 m/s; CI: [0.625, 0.891] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.004641588833612777, 'tau_d': 499.99999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     Removed 20 simulations where ped. did not enter conflict space.
#                     TTCA = 8 s: Av: 0.672 m/s; CI: [0.537, 0.807] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.007742636826811269, 'tau_d': 499.99999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.596 m/s; CI: [0.471, 0.722] m/s
#                             Passed.
#     Model oVAoEAoSNv; ('T', 'DeltaV_th_rel', 'tau_theta'):
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.089 m/s; CI: [1.000, 1.177] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.118 m/s; CI: [1.034, 1.203] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.096 m/s; CI: [1.020, 1.172] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.123 m/s; CI: [1.052, 1.193] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.930 m/s; CI: [0.808, 1.051] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.032 m/s; CI: [0.950, 1.115] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.876 m/s; CI: [0.754, 0.997] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.851 m/s; CI: [0.722, 0.981] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.676 m/s; CI: [0.551, 0.801] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.070 m/s; CI: [0.982, 1.159] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.008 m/s; CI: [0.901, 1.115] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.793 m/s; CI: [0.676, 0.910] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.536 m/s; CI: [0.430, 0.641] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.712 m/s; CI: [0.595, 0.828] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.783 m/s; CI: [0.654, 0.912] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.610 m/s; CI: [0.487, 0.733] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.641 m/s; CI: [0.513, 0.768] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.375 m/s; CI: [0.318, 0.432] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.589 m/s; CI: [0.474, 0.703] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.569 m/s; CI: [0.456, 0.681] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.475 m/s; CI: [0.382, 0.568] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.484 m/s; CI: [0.387, 0.581] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.463 m/s; CI: [0.369, 0.558] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.768 m/s; CI: [0.670, 0.866] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.941 m/s; CI: [0.853, 1.028] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.858 m/s; CI: [0.762, 0.954] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.832 m/s; CI: [0.731, 0.934] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.888 m/s; CI: [0.791, 0.986] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.903 m/s; CI: [0.807, 1.000] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.943 m/s; CI: [0.845, 1.042] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.790 m/s; CI: [0.697, 0.884] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.953 m/s; CI: [0.868, 1.038] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.904 m/s; CI: [0.815, 0.993] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.868 m/s; CI: [0.768, 0.968] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.893 m/s; CI: [0.794, 0.991] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.955 m/s; CI: [0.856, 1.053] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.809 m/s; CI: [0.695, 0.923] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.546 m/s; CI: [0.446, 0.647] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.588 m/s; CI: [0.482, 0.693] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.879 m/s; CI: [0.796, 0.961] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.756 m/s; CI: [0.659, 0.853] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.923 m/s; CI: [0.829, 1.017] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.868 m/s; CI: [0.760, 0.976] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.434 m/s; CI: [0.375, 0.492] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.535 m/s; CI: [0.447, 0.622] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.520 m/s; CI: [0.430, 0.609] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.463 m/s; CI: [0.377, 0.550] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.860 m/s; CI: [0.768, 0.952] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.513 m/s; CI: [0.443, 0.583] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.492 m/s; CI: [0.417, 0.567] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.581 m/s; CI: [0.489, 0.673] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.471 m/s; CI: [0.394, 0.549] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.416 m/s; CI: [0.355, 0.477] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.438 m/s; CI: [0.365, 0.511] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.383 m/s; CI: [0.325, 0.441] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.438 m/s; CI: [0.370, 0.506] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.401 m/s; CI: [0.347, 0.455] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.403 m/s; CI: [0.343, 0.463] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.391 m/s; CI: [0.335, 0.447] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.356 m/s; CI: [0.318, 0.394] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.455 m/s; CI: [0.374, 0.535] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.355 m/s; CI: [0.354, 0.356] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.372 m/s; CI: [0.329, 0.414] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.365 m/s; CI: [0.324, 0.407] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.358 m/s; CI: [0.318, 0.398] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.030 m/s; CI: [0.958, 1.103] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.990 m/s; CI: [0.899, 1.082] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.017 m/s; CI: [0.930, 1.103] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.951 m/s; CI: [0.845, 1.057] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.965 m/s; CI: [0.882, 1.048] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.912 m/s; CI: [0.815, 1.008] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.838 m/s; CI: [0.733, 0.943] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.051 m/s; CI: [0.969, 1.132] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.944 m/s; CI: [0.843, 1.045] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.959 m/s; CI: [0.851, 1.068] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.820 m/s; CI: [0.701, 0.939] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.026 m/s; CI: [0.949, 1.102] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.910 m/s; CI: [0.809, 1.010] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.919 m/s; CI: [0.815, 1.024] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.765 m/s; CI: [0.659, 0.871] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.773 m/s; CI: [0.655, 0.890] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.667 m/s; CI: [0.554, 0.780] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.707 m/s; CI: [0.591, 0.823] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.870 m/s; CI: [0.768, 0.972] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.810 m/s; CI: [0.705, 0.915] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.704 m/s; CI: [0.596, 0.811] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.743 m/s; CI: [0.634, 0.852] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.585 m/s; CI: [0.482, 0.687] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.661 m/s; CI: [0.543, 0.780] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.442 m/s; CI: [0.372, 0.512] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.665 m/s; CI: [0.556, 0.774] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.724 m/s; CI: [0.604, 0.845] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.499 m/s; CI: [0.411, 0.587] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.560 m/s; CI: [0.452, 0.667] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.428 m/s; CI: [0.351, 0.504] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.522 m/s; CI: [0.431, 0.613] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.518 m/s; CI: [0.421, 0.615] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.479 m/s; CI: [0.391, 0.568] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.388 m/s; CI: [0.332, 0.445] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.399 m/s; CI: [0.333, 0.464] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.001, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.221 m/s; CI: [1.179, 1.264] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.204 m/s; CI: [1.144, 1.263] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.045 m/s; CI: [0.943, 1.146] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.902 m/s; CI: [0.780, 1.023] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.067 m/s; CI: [0.976, 1.157] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     Removed 10 simulations where ped. did not enter conflict space.
#                     TTCA = 8 s: Av: 1.084 m/s; CI: [0.984, 1.185] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.856 m/s; CI: [0.732, 0.979] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.700 m/s; CI: [0.576, 0.824] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     Removed 1 simulations where ped. did not enter conflict space.
#                     TTCA = 8 s: Av: 0.731 m/s; CI: [0.602, 0.859] m/s
#                             Passed.
#     Model oVAoEAoSNvoPF; ('T', 'DeltaV_th_rel', 'tau_theta'):
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.004999999999999999}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.271 m/s; CI: [1.223, 1.319] m/s
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.010772173450159416}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.178 m/s; CI: [1.122, 1.234] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.010772173450159416}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.195 m/s; CI: [1.136, 1.254] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.010772173450159416}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.194 m/s; CI: [1.107, 1.281] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.010772173450159416}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.187 m/s; CI: [1.112, 1.262] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.010772173450159416}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.233 m/s; CI: [1.175, 1.290] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.010772173450159416}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.161 m/s; CI: [1.076, 1.247] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.021544346900318832, 'tau_theta': 0.010772173450159416}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     Removed 8 simulations where ped. did not enter conflict space.
#                     TTCA = 8 s: Av: 1.211 m/s; CI: [1.151, 1.271] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.023207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.238 m/s; CI: [1.179, 1.296] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.023207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.218 m/s; CI: [1.163, 1.272] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.023207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.236 m/s; CI: [1.198, 1.274] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.023207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.165 m/s; CI: [1.086, 1.245] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.023207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.149 m/s; CI: [1.060, 1.238] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.023207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.057 m/s; CI: [0.949, 1.165] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.023207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.208 m/s; CI: [1.141, 1.275] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.158 m/s; CI: [1.094, 1.221] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.158 m/s; CI: [1.097, 1.218] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.155 m/s; CI: [1.085, 1.224] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.095 m/s; CI: [1.021, 1.170] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.232 m/s; CI: [1.182, 1.282] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.102 m/s; CI: [1.009, 1.194] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.121 m/s; CI: [1.045, 1.197] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.019 m/s; CI: [0.919, 1.119] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.110 m/s; CI: [0.998, 1.222] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.080 m/s; CI: [0.991, 1.169] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.036 m/s; CI: [0.944, 1.129] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.036 m/s; CI: [0.920, 1.152] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.937 m/s; CI: [0.815, 1.059] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.906 m/s; CI: [0.779, 1.034] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.818 m/s; CI: [0.696, 0.940] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.049999999999999996}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.980 m/s; CI: [0.857, 1.103] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.176 m/s; CI: [1.108, 1.244] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.095 m/s; CI: [1.008, 1.183] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.038 m/s; CI: [0.950, 1.125] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.107 m/s; CI: [1.017, 1.197] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.182 m/s; CI: [1.110, 1.253] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.037 m/s; CI: [0.939, 1.136] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.046 m/s; CI: [0.938, 1.154] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.064 m/s; CI: [0.989, 1.139] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.051 m/s; CI: [0.959, 1.143] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.037 m/s; CI: [0.920, 1.154] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.032 m/s; CI: [0.929, 1.136] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.995 m/s; CI: [0.888, 1.103] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.820 m/s; CI: [0.703, 0.936] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.050 m/s; CI: [0.959, 1.141] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.944 m/s; CI: [0.833, 1.055] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.035 m/s; CI: [0.936, 1.134] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.024 m/s; CI: [0.915, 1.133] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.926 m/s; CI: [0.794, 1.059] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.098 m/s; CI: [1.008, 1.188] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.117 m/s; CI: [1.056, 1.178] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.013 m/s; CI: [0.919, 1.107] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.026 m/s; CI: [0.912, 1.139] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.060 m/s; CI: [0.951, 1.169] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.110 m/s; CI: [1.023, 1.196] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.148 m/s; CI: [1.077, 1.220] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.067 m/s; CI: [0.976, 1.159] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.034 m/s; CI: [0.923, 1.145] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.045 m/s; CI: [0.958, 1.131] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.136 m/s; CI: [1.053, 1.219] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.012 m/s; CI: [0.886, 1.139] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.000 m/s; CI: [0.886, 1.115] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.877 m/s; CI: [0.753, 1.002] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.979 m/s; CI: [0.871, 1.087] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.998 m/s; CI: [0.891, 1.106] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.980 m/s; CI: [0.863, 1.097] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.900 m/s; CI: [0.768, 1.032] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.007 m/s; CI: [0.894, 1.119] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.807 m/s; CI: [0.685, 0.930] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.156 m/s; CI: [1.088, 1.225] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.301] m/s
#                     TTCA = 8 s: Av: 1.078 m/s; CI: [0.983, 1.173] m/s
#                             Passed.
#             {'T': 0.5, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     Removed 3 simulations where ped. did not enter conflict space.
#                     TTCA = 8 s: Av: 1.147 m/s; CI: [1.059, 1.234] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.144 m/s; CI: [1.063, 1.225] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.086 m/s; CI: [0.979, 1.194] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.019 m/s; CI: [0.910, 1.127] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.012 m/s; CI: [0.909, 1.114] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.861 m/s; CI: [0.733, 0.990] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.010 m/s; CI: [0.901, 1.120] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 0.974 m/s; CI: [0.859, 1.089] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.021 m/s; CI: [0.913, 1.129] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.869 m/s; CI: [0.759, 0.979] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.961 m/s; CI: [0.842, 1.080] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.930 m/s; CI: [0.803, 1.056] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.848 m/s; CI: [0.728, 0.968] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.861 m/s; CI: [0.735, 0.987] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     Removed 11 simulations where ped. did not enter conflict space.
#                     TTCA = 8 s: Av: 0.929 m/s; CI: [0.805, 1.054] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.001, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.094 m/s; CI: [0.999, 1.189] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.095 m/s; CI: [1.012, 1.179] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.073 m/s; CI: [0.987, 1.158] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.038 m/s; CI: [0.953, 1.123] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.024 m/s; CI: [0.925, 1.122] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.897 m/s; CI: [0.770, 1.025] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.943 m/s; CI: [0.831, 1.056] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.977 m/s; CI: [0.858, 1.095] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.886 m/s; CI: [0.760, 1.012] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.987 m/s; CI: [0.888, 1.085] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.295 m/s; CI: [1.286, 1.304] m/s
#                     TTCA = 8 s: Av: 0.924 m/s; CI: [0.802, 1.047] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.994 m/s; CI: [0.873, 1.114] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 1.077217345015941}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.836 m/s; CI: [0.709, 0.962] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.001, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.136 m/s; CI: [1.038, 1.234] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.125 m/s; CI: [1.045, 1.205] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.184 m/s; CI: [1.108, 1.260] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.073 m/s; CI: [0.994, 1.152] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.050 m/s; CI: [0.962, 1.138] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.049 m/s; CI: [0.952, 1.146] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.295 m/s; CI: [1.287, 1.304] m/s
#                     TTCA = 8 s: Av: 0.778 m/s; CI: [0.656, 0.899] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.001 m/s; CI: [0.903, 1.100] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.802 m/s; CI: [0.665, 0.938] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     Removed 10 simulations where ped. did not enter conflict space.
#                     TTCA = 8 s: Av: 0.982 m/s; CI: [0.860, 1.103] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.846 m/s; CI: [0.733, 0.959] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.891 m/s; CI: [0.764, 1.018] m/s
#                             Passed.
#             {'T': 0.2445212848097688, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 2.3207944168063883}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.810 m/s; CI: [0.674, 0.946] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.172 m/s; CI: [1.108, 1.235] m/s
#                             Passed.
#             {'T': 0.11958131745004018, 'DeltaV_th_rel': 0.001, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.072 m/s; CI: [0.986, 1.158] m/s
#                             Passed.
#             {'T': 0.2044811765114791, 'DeltaV_th_rel': 0.001, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.137 m/s; CI: [1.055, 1.219] m/s
#                             Passed.
#             {'T': 0.3496578933827813, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.078 m/s; CI: [0.966, 1.191] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0016681005372000592, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.034 m/s; CI: [0.914, 1.154] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.147 m/s; CI: [1.059, 1.234] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.063 m/s; CI: [0.978, 1.148] m/s
#                             Passed.
#             {'T': 0.2924017738212866, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.029 m/s; CI: [0.911, 1.147] m/s
#                             Passed.
#             {'T': 0.4181255154751867, 'DeltaV_th_rel': 0.0027825594022071257, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.299 m/s; CI: [1.298, 1.301] m/s
#                     TTCA = 8 s: Av: 0.907 m/s; CI: [0.784, 1.030] m/s
#                             Passed.
#             {'T': 0.14299691483087287, 'DeltaV_th_rel': 0.004641588833612777, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.001 m/s; CI: [0.902, 1.100] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.007 m/s; CI: [0.897, 1.117] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.007742636826811269, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.004 m/s; CI: [0.894, 1.114] m/s
#                             Passed.
#             {'T': 0.17099759466766973, 'DeltaV_th_rel': 0.01291549665014884, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.834 m/s; CI: [0.711, 0.957] m/s
#                             Passed.
#     Model oVAoSNv; ('tau_theta',):
#             {'tau_theta': 0.10772173450159415}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.202 m/s; CI: [1.183, 1.220] m/s
#                             Passed.
#             {'tau_theta': 0.23207944168063885}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.100 m/s; CI: [1.055, 1.146] m/s
#                             Passed.
#             {'tau_theta': 0.49999999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.122 m/s; CI: [1.080, 1.164] m/s
#                             Passed.
#
#     ********** Summary **********
#
#     Model oVAoAN; ('sigma_V',):
#             Pedestrian hesitation verified in 0 out of 1 parameterisations (0.0 %).
#
#     Model oVAoEAoAN; ('T', 'DeltaV_th_rel', 'sigma_V'):
#             Pedestrian hesitation verified in 0 out of 70 parameterisations (0.0 %).
#
#     Model oVAoEAoSNc; ('T', 'DeltaV_th_rel', 'tau_d'):
#             Pedestrian hesitation verified in 5 out of 5 parameterisations (100.0 %).
#
#     Model oVAoEAoSNv; ('T', 'DeltaV_th_rel', 'tau_theta'):
#             Pedestrian hesitation verified in 109 out of 109 parameterisations (100.0 %).
#
#     Model oVAoEAoSNvoPF; ('T', 'DeltaV_th_rel', 'tau_theta'):
#             Pedestrian hesitation verified in 124 out of 125 parameterisations (99.2 %).
#
#     Model oVAoSNv; ('tau_theta',):
#             Pedestrian hesitation verified in 3 out of 3 parameterisations (100.0 %).
#
# >>>
