# %% [markdown]
# # 2022-07-20 Medium-scale probabilistic fits with decision evidence accumulation
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/846fe233aa5bf2d59bfc173d519b86096eafb4bd
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# As a first more complete test to see how the new `oDA` assumption is working, running the probabilistic fits for all models, with the same 5-value grid as in previous "medium-scale" probabilistic fits (most recently 2022-01-13):
#
#     # - models
#     BASE_MODELS = ('oVA', 'oVAoEA', 'oVAoDA')
#     MODEL_VARIANTS = ('oAN', 'oSNc', 'oSNv', 'oSNcoPF', 'oSNvoPF')
#
#     # - free parameter values
#     N_VALS_PER_PARAM = 5
#     PARAM_ARRAYS = {}
#     PARAM_ARRAYS['T'] = np.logspace(np.log10(0.1), np.log10(0.5), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['DeltaV_th_rel'] = np.logspace(np.log10(0.001), np.log10(0.1), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['sigma_V'] = np.logspace(np.log10(0.001), np.log10(1), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['tau_theta'] = np.logspace(np.log10(0.005), np.log10(5), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['tau_d'] = np.logspace(np.log10(0.5), np.log10(500), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['xi_th'] = np.logspace(np.log10(5e-6), np.log10(5e-3), N_VALS_PER_PARAM)
#
# Comparing the percentages of criterion achievement for the previously existing models below to the same percentages in the 2022-02-03 diary notes (that is for a full-scale probabilistic run - but comparing to this one since it has the "pedestrian progress" criterion which wasn't in place yet in the 2022-01-13 run, and also I am not sure if there may have been other changes?) - my conclusion is that I can't see any indications of any major change in behaviour for any of these model variants. Which is what I wanted to see.
#
# Looking at the results for the `oDA` model variants I am happy to see that they do noticeably better than their `oEA` counterparts in terms of achieving collision-free interactions and pedestrian progress in the constant-speed scenario. Just a little bit of non-progress for the `oVAoDAoSNcoPF` model but otherwise 100% criterion achievement.
#
# In terms of gap acceptance hesitation, the `oDA` model variants do quite similarly to their `oEA` counterparts - only seemingly a little rarer that the `oDA` model variant reduces speed in all five scenario repetitions - it instead seems to do both substantial speed reductions and substantial speed increases.
#
# The $\xi_\mathrm{th}$ parameter ranges also look like they were pretty ok, from the retained parameterisations.
#
# Next steps:
# * Roll back the medium-scale fits for the previously existing models, restoring the results from the previous full-scale fits of those.
# * Run full-scale probabilistic fits for the `oDA` model variants, with the same parameter ranges as here.

# %%
# %run ../SCPaper/do_6_analyse_probabilistic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoDAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoDAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoDAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoDAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoDAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNcoPF.pkl', 'C:\\G
# ...
