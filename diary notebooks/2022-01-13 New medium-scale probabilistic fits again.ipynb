# %% [markdown]
# # 2022-01-13 New medium-scale probabilistic fits again
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/1aeaf2e2b8feaeb2d8f3c450e9650f98432ad950
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Rerunning the same tests as 2022-01-08, just to verify that nothing weird has happened since then - which it doesn't seem to have.
#
# Further below also output from the extra pedestrian hesitation check, again all seems fine (same conclusions as previously, most recently 2022-01-07e).
#
# So next I think I should:
# * Run full-scale probabilistic fits on ARC4. I can still use the same release as for the most recent deterministic fits (reported on in the 2022-01-12 notes), since the only code changes since then are in output analysis scripts etc, as can be seen here: https://github.com/gmarkkula/COMMOTIONSFramework/compare/27bdaf1..1aeaf2e
# * Run medium-scale combined fits on my computer. This would be a good time to add and test functionality for only including a subset of the retained deterministic parameters for models with many retained parameterisations, as planned in the 2022-01-05b notes.

# %%
# %run ../SCPaper/do_6_analyse_probabilistic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNvoPF.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\ProbFit_oVAoAN.pkl"...
# 	Done.
# Analysing model oVAoAN, 5 parameterisations...
# 		Collision-free encounter: Found 5 (100.0 %) parameterisations.
# ...

# %% [markdown]
# ## Pedestrian hesitation check
#
# Output from `do_7_check_hesitation.py`:
#
#     Starting pool of workers...
#     Model oVAoAN; ('sigma_V',):
#             {'sigma_V': 0.1778279410038923}...
#                     TTCA = -3 s: Av: 1.048 m/s; CI: [0.965, 1.131] m/s
#                     TTCA = 8 s: Av: 1.146 m/s; CI: [1.066, 1.226] m/s
#     Model oVAoEAoAN; ('T', 'DeltaV_th_rel', 'sigma_V'):
#             {'T': 0.1, 'DeltaV_th_rel': 0.0031622776601683794, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.142 m/s; CI: [1.059, 1.225] m/s
#                     TTCA = 8 s: Av: 1.151 m/s; CI: [1.098, 1.204] m/s
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.0031622776601683794, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.066 m/s; CI: [0.971, 1.160] m/s
#                     TTCA = 8 s: Av: 1.159 m/s; CI: [1.082, 1.235] m/s
#             {'T': 0.1, 'DeltaV_th_rel': 0.01, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.109 m/s; CI: [1.037, 1.181] m/s
#                     TTCA = 8 s: Av: 1.215 m/s; CI: [1.159, 1.271] m/s
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.03162277660168379, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.225 m/s; CI: [1.130, 1.320] m/s
#                     TTCA = 8 s: Av: 1.274 m/s; CI: [1.166, 1.382] m/s
#             {'T': 0.5, 'DeltaV_th_rel': 0.03162277660168379, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.494 m/s; CI: [1.333, 1.655] m/s
#                     TTCA = 8 s: Av: 1.424 m/s; CI: [1.293, 1.555] m/s
#             {'T': 0.5, 'DeltaV_th_rel': 0.1, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.186 m/s; CI: [1.065, 1.307] m/s
#                     TTCA = 8 s: Av: 1.309 m/s; CI: [1.198, 1.420] m/s
#     Model oVAoEAoSNc; ('T', 'DeltaV_th_rel', 'tau_d'):
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.01, 'tau_d': 499.99999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.537 m/s; CI: [0.427, 0.647] m/s
#                             Passed.
#     Model oVAoEAoSNv; ('T', 'DeltaV_th_rel', 'tau_theta'):
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.933 m/s; CI: [0.849, 1.018] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.960 m/s; CI: [0.866, 1.054] m/s
#                             Passed.
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.900 m/s; CI: [0.806, 0.993] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.952 m/s; CI: [0.860, 1.043] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.985 m/s; CI: [0.894, 1.076] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.517 m/s; CI: [0.422, 0.612] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.428 m/s; CI: [0.355, 0.501] m/s
#                             Passed.
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.335 m/s; CI: [0.334, 0.336] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.173 m/s; CI: [1.119, 1.227] m/s
#                             Passed.
#             {'T': 0.334370152488211, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.989 m/s; CI: [0.883, 1.096] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.827 m/s; CI: [0.707, 0.947] m/s
#                             Passed.
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.786 m/s; CI: [0.661, 0.911] m/s
#                             Passed.
#     Model oVAoEAoSNvoPF; ('T', 'DeltaV_th_rel', 'tau_theta'):
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.02811706625951745}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.203 m/s; CI: [1.143, 1.262] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.02811706625951745}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.173 m/s; CI: [1.109, 1.237] m/s
#                             Passed.
#             {'T': 0.334370152488211, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.02811706625951745}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.069 m/s; CI: [0.967, 1.171] m/s
#                             Passed.
#             {'T': 0.5, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.02811706625951745}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: nan m/s; CI: [nan, nan] m/s
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.167 m/s; CI: [1.096, 1.237] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.946 m/s; CI: [0.832, 1.059] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.965 m/s; CI: [0.850, 1.081] m/s
#                             Passed.
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.850 m/s; CI: [0.715, 0.985] m/s
#                             Passed.
#             {'T': 0.334370152488211, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.067 m/s; CI: [0.960, 1.174] m/s
#                             Passed.
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.115 m/s; CI: [1.019, 1.211] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.894 m/s; CI: [0.776, 1.013] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.140 m/s; CI: [1.070, 1.210] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.001, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.083 m/s; CI: [0.995, 1.171] m/s
#                             Passed.
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.001, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.092 m/s; CI: [1.001, 1.184] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.104 m/s; CI: [1.015, 1.193] m/s
#                             Passed.
#             {'T': 0.334370152488211, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.979 m/s; CI: [0.865, 1.093] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.01, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.925 m/s; CI: [0.807, 1.043] m/s
#                             Passed.
#     Model oVAoSNv; ('tau_theta',):
#             {'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.157 m/s; CI: [1.122, 1.192] m/s
#                             Passed.
