# %% [markdown]
# # 2021-12-01 Rerunning a selection of the deterministic fits after the minor bug fixes
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/4b1d8dea7998066f652131835a1cd7653f2c707b (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Rerunning the `oVA*` fits for the larger parameter grid. The results are as expected after the notes from Nov 27-29.
#
# Below I have also modified the cutoffs a little bit for priority assertion and short-stopping - with the current settings `DetFit_oVAaoVAloBEooBEvoAI` does achieve all four main criteria across parameterisations, but not more than two at a time for any single parameterisation.
#
# Thoughts on next steps, still on this branch:
# * My impression is that the difference between results here and 2021-10-29 is due to the differences in kinematics introduced by adding the agent width/length support, and splitting up the scenarios to prepare for the probabilistic fitting. In other words, the ability of the models to meet the criteria is kinematics-dependent (more so than I thought). Therefore I am considering expanding the deterministic fits to include some kinematical variations of each scenario.
# * Speed-ups of the deterministic fits from ending simulation early when possible.
# * Modifying `sc_fitting.metric_veh_av_surpl_dec()` to disregard the first second of so of acceleration behaviour, which tends to force the average surplus acceleration to negative values even when there are signs of short-stopping, due to acceleration starting from zero.

# %%
# %run ../SCPaper/do_2_analyse_deterministic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVA.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAa.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoVAl.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoVAloBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoVAloBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoVAloBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoVAloBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoVAloBEvoAI.pkl', 'C:\\GITH
# ...
