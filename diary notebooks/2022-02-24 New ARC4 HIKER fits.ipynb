# %% [markdown]
# # 2022-02-24 New ARC4 HIKER fits
#
# Results below are from:
#
# * An ARC4 run using this release: https://github.com/gmarkkula/COMMOTIONSFramework/releases/tag/v0.2.5.10
# * And analysis code from commit: ###
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# This ARC4 run of `do_11...` across 8415 model parameterisations (summed across all models) took 33.1 h, or about 14 s per parameterisation.
#
# Results below. Now including all tested combined parameterisations, in contrast with the same plots in the 2022-01-28 diary notes, where I excluded parameterisations with excessive amounts of non-crossing. I was hoping that my tweaks since then, to the parameterisation retention approach for the probabilistic and combined fits, would have reduced the tendency for non-crossing back to the near-zero levels I was seeing in the results in the 2022-01-02 diary notes, but this is not the case. I still have about 30% non-crossing in many models. For the `oVA` models, this non-crossing is only happening for the models with both `oEA` and `oPF`, but for the `oVAa` models also some models with only `oEA` and not `oPF` show non-crossing.
#
# Next steps should include some or all of:
# * Trying to understand why the tendency for non-crossing persists in these vehicle yielding scenarios, despite excluding model parameterisations who showed non-crossing in the constant-speed gap acceptance hesitation scenario in the probabilistic and combined fits. What is the mechanism causing this non-crossing?
# * Checking what the results look like if I apply a more principled parameterisation exclusion criterion, for example requiring crossing in all yielding HIKER scenarios, but not in the constant-speed HIKER scenarios.
#     * What parameterisations get excluded? Might also help answer the first question above.
#     * What do the CIT CDFs look like for the retained parameterisations?

# %%
# %run ../SCPaper/do_12_analyse_HIKER_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEooBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEooBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEooBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEooBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEooBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEooBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEooBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEooBEvoAIoSNv.pkl', 'C:\\G
# ...
