# %% [markdown]
# # 2022-07-20b Full-scale probabilistic fits - including decision evidence accumulation
#
# Results below are for commit: ###
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# I have now run full-scale probabilistic fits of the model variants with `oDA`, as planned in the other diary notes from earlier today. I restored the old full-scale probabilistic fitting results for the other model variants (rather than rerunning them), so overall I now have results for this set of models and parameter grids:
#
#     # - models
#     BASE_MODELS = ('oVA', 'oVAoEA', 'oVAoDA')
#     MODEL_VARIANTS = ('oAN', 'oSNc', 'oSNv', 'oSNcoPF', 'oSNvoPF')
#
#     # - free parameter values
#     N_VALS_PER_PARAM = 10
#     PARAM_ARRAYS = {}
#     PARAM_ARRAYS['T'] = np.logspace(np.log10(0.1), np.log10(0.5), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['DeltaV_th_rel'] = np.logspace(np.log10(0.001), np.log10(0.1), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['sigma_V'] = np.logspace(np.log10(0.001), np.log10(1), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['tau_theta'] = np.logspace(np.log10(0.005), np.log10(5), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['tau_d'] = np.logspace(np.log10(0.5), np.log10(500), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['xi_th'] = np.logspace(np.log10(5e-6), np.log10(5e-3), N_VALS_PER_PARAM)
#
# I am getting back exactly the same results for the previously existing models, as I should.
#
# The results from the medium-scale fits of the `oDA` models from earlier today still hold with this finer-grained search grid. The only change is that what I noted in those notes earlier today about the `oDA` model variants not having as big a tendency to reduce speed in all five repetitions, that impression now disappears - presumably the coarse grid wasn't hitting some sweet spot intermediate $\xi_\mathrm{th}$ values.
#
# And the `oDA` variants still look like they are providing a big improvement over the `oEA` variants in terms of not getting stuck - which is great since this is precisely what I was hoping to achieve. Remains to be seen to what extent this still applies in the combined fits and in the two-agent simulations. However, we can see already now in the interaction outcome plot at the bottom below that the instances of no agent exiting first (orange in the bar plots) and the instances of pedestrian not exiting (the rightmost bins in the histograms) are reduced in the `oDA` model variants compared to the corresponding `oEA` model variants. But not zero. So even though we are just looking at the retained parameterisations here, some tendencies to get stuck still seem to be there. To be fair that is true also for the model variants completely without any accumulation whatsoever. We can definitely press on with the `oDA` variants along the model fitting pipeline.
#
# Next steps:
# * Run the gap acceptance hesitation checks for the retained `oDA` model variants and parameterisations.
# * Run combined fits with retained `oDA` model variants and parameterisations.

# %%
# %run ../SCPaper/do_6_analyse_probabilistic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoDAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoDAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoDAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoDAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoDAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNcoPF.pkl', 'C:\\G
# ...
