# %% [markdown]
# # 2021-12-05 Deterministic fits across kinematic scenario variants with expanded grid
#
# Results below are for commit: ### (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Running the full set of deterministic fits (all 36 model variants, the larger parameter grid), after having added in the kinematic scenario variants. This is making me think that I should have added these variants in long ago. The `oVAoBE*` models are actually capable of pedestrian start before vehicle stop, after all. In the `do_2...` run below, I have set:
#
#     SPEEDUP_FRACT = 1.01
#     SURPLUS_DEC_THRESH = 2 # m/s^2
#
# For which a nicely logically consistent set of models achieve all four main criteria, with `oVAoBEvoAI` as the lowest-complexity alternative, which is even able to meet all four criteria in a single parameterisation.
#
# Lowering the thresholds above, some other models naturally start meeting more criteria, the first to meet all four is interestingly `oVAoVAloBEo` which meets all four at (1.005, 1) for the thresholds above.
#
# One notable aspect is that the non-`oVA` models don't achieve priority assertion or short-stopping at all. In the 2021-11-03 fits, `oBEvoAI` achieved both, but the short-stopping there can be explained with the imperfect definition of that criterion (based on the max value rather than the mean value) which essentially had all models short-stopping, and the priority assertion was actually only for one single parameterisation, and looking more closely at the behaviour probabilities in that simulation they look kind of strange. Possibly it had something to do with the bug I mentioned and fixed in the 2021-11-16 notes...?
#
# Next steps / for the todo list:
# * Rerun a subset of this stuff on ARC to check if I get the same results back.
# * Do a sensitivity analysis on the criterion thresholds.
# * Start running probabilistic fits. My current thinking is that this could start first with just the base `oVA` model (since as seen 2021-11-12, already that model should be capable of pedestrian hesitation in the constant-speed scenario), and then also the models retained from the deterministic fits.

# %%
# %run ../SCPaper/do_2_analyse_deterministic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVA.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAa.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/re
# ...
