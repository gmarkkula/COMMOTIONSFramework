# %% [markdown]
# # 2021-10-20 Same deterministic fits again, just finer-grained time step and action space
#
# Results below are for commit: ### (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Just rerunning the same deterministic fits as in yesterday's notes, but decreasing time step $\Delta t$ from 0.1 s to 0.02 s, and increasing the action set from $\{-1, -0.5, ...,  1 \}$ to $\{-1, -0.75, ...,  1 \}$.
#
# We can see that we now basically get back results from before introducing the safety margins, where the `oVAoBEvoAI` and `oVAaoBEooBEooAI` are the only two models to meet all four of the main criteria, but again they do so by only a very minute tendency of the pedestrian to start before the vehicle is at a full stop in the `ActPedPrioEncounter` scenario. My overall impression here is that the qualitative behaviour of the models does not change substantially by making time step and action space more fine grained - and that is positive, because these fits take about ten times longer to run...
#
# So the conclusion here for me is that I think it is time to try that numerical integration over the prediction horizon approach that I mentioned in the previous diary entry, first for just the basic `oVA`/`oVAa` calculations, and then also for `oVAl`. If neither of that helps resolve the `ActPedPrioEncounter` conundrum, then maybe it's time to give up on that specific thing. It is worth remembering that I don't actually have data on that exact scenario (with an initially walking pedestrian), so I may trying to achieve something here that humans don't do. It just seems very logical based on the other existing data, and everyday experience, that they would behave in this way.

# %%
# %run ../SCPaper/do_2_analyse_deterministic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVA.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAa.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit
# ...
