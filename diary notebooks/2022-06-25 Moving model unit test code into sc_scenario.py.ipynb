# %% [markdown]
# # 2022-06-25 Moving "model unit test" code into sc_scenario.py
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/62b41b0d52f619e9a52b373c50a30e3b58b08ed1
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Before adding the `oDA` functionality I wanted to run through my "unit tests" of the model, both to compare to the previous such tests which were done a while ago now (2022-01-11b diary notes), and to add a new test including `oEA` that I could compare against after adding `oDA`, to verify that it doesn't change the `oEA` model behaviour. I took this opportunity to reduce future code copying a bit by moving those unit tests from these diary notebooks into `sc_scenario.py` itself. Since implementing the various convenience wrappers in `sc_fitting.py` I have only rarely used the ad hoc testing code in the `__main__` of `sc_scenario.py`, so I replaced that ad hoc testing code with the "unit tests", and added a `oEA` test -  so running `sc_scenario.py` now runs the unit tests.
#
# As can be seen below, for the tests that were also in the 2022-01-11b diary notes (all except the new `oEA` test), the model still behaves the same,  as I was expecting/hoping.

# %%
# %run ../sc_scenario.py
# Out:
# ***** Base model, just startup *****
# ***** Base model, baseline kinematics *****
#
# Initial car distance 30 m:
# Initial car distance 40 m:
# Initial car distance 50 m:
# ***** Enabling behaviour observation assumptions *****
#
# Turning on oBEo:
# Turning on oBEv:
# Turning on oAI:
# ***** Enabling evidence accumulation *****
#
# Initial car distance 30 m:
# Initial car distance 50 m:
