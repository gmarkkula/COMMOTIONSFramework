# %% [markdown]
# # WIP Closer look at the deterministic fits
#
# Results below are for commit: ###
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# I have now created a plot for the long since planned sensitivity analysis on the deterministic criteria thresholds. See far below for some conclusions.

# %%
# %run ../SCPaper/do_2_analyse_deterministic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVA.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAa.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/re
# ...

# %% [markdown]
# ## Priority assertion
# * The base (non-affordance) model can't do it.
# * The `oVAa` model can do it, but only with the addition of both `oVAl` and `oBEvoAI`
# * The `oVA` model can do it with `oBEvoAI` alone
# * When `oVAl` is added to `oVA`, any `oBE*` addition is enough.
#
# In sum, the simplest model that can do priority assertion is `oVAoBEvoAI`, and other `oBE*` combinations can only do it if combined with `oVAl`.
#
# ## Short-stopping
# I should create a figure like the one above also for the separate short-stopping check before looking at this in detail.
#
# ## Pedestrian hesitation in deceleration scenario
# All models can do this.
#
# ## Early pedestrian crossing
# * The base (non-affordance) model can do this quite easily.
# * The affordance-based models can't do this in their simplest form, but they can with the addition of any `oBE*`.
#
# ## Pedestrian hesitation in constant-speed scenario
# * Without any `oBE*` assumptions, none of the models can do it.
# * Adding `oBEo` makes any model capable of doing it, but as we have seen in the above results, only for model parameterisations which don't meet at least two of the other criteria.
# * For the non-affordance-based model and for `oVAaoVAl`, there are also other `oBE*` combinations besides pure `oBEo` that are capable of doing it, but again only for parameterisations which don't meet at least two of the other criteria.
#
# In sum, there are ways of getting the deterministic models to do pedestrian hesitation in the constant-speed scenario, especially using the `oBEo` assumption, but not while also achieving the other phenomena.
