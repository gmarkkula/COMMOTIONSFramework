# %% [markdown]
# # 2021-12-06 Testing a subset of deterministic fits on ARC4
#
# I tested deterministic fitting of a subset of the models, as specified in this commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/49e3613ff4a0eaa209c9ddb87966b793b5348f92
#
# As can be seen in the `do_1.sh` SGE bath job file, this is using the `base` conda environment provided by ARC4. Added to todolist: Try specifying the exact python and package versions in a conda yml file.
#
# More specifically I tested:
#
#     BASE_MODELS = ('', 'oVA', 'oVAaoVAl')
#     MODEL_VARIANTS = ('', 'oBEvoAI')
#
# Below I am pasting the output from `do_2...` on the server, showing exactly the same results (in terms of the number of parameterisations meeting each criterion for each model) as in the 2021-12-05 diary notes. I am not saving the output .pkl files anywhere, just taking this as a confirmation that I am getting the same results from ARC4 as from my own computer.
#
#
# ---
#
#     (base) [tragma@login1.arc4 SCPaper]$ python do_2_analyse_deterministic_fits.py
#     ['/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_.pkl', '/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_oBEvoAI.pkl', '/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_oVA.pkl', '/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_oVAaoVAl.pkl', '/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_oVAaoVAloBEvoAI.pkl', '/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_oVAoBEvoAI.pkl']
#
#     Loading parameter search from file "/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_.pkl"...
#             Done.
#     Analysing model , 100 parameterisations...
#             Main criteria:
#                     Vehicle asserting priority: Found 0 (0.0 %) parameterisations.
#                     Vehicle short-stopping: Found 0 (0.0 %) parameterisations.
#                     Pedestrian hesitation in deceleration scenario: Found 80 (80.0 %) parameterisations.
#                     Pedestrian starting before vehicle at full stop: Found 90 (90.0 %) parameterisations.
#             Secondary criteria:
#                     Pedestrian hesitation in constant-speed scenario: Found 0 (0.0 %) parameterisations.
#             All main criteria met: Found 0 (0.0 %) parameterisations.
#             Max no of main criteria met was 2, for 70 parameterisations.
#                     Out of these, the max number of secondary criteria met was 0, for 70 parameterisations.
#             NaNs in main crit: [0 0 0 0]; sec crit: [0]
#
#     Loading parameter search from file "/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_oBEvoAI.pkl"...
#             Done.
#     Analysing model oBEvoAI, 1000 parameterisations...
#             Main criteria:
#                     Vehicle asserting priority: Found 0 (0.0 %) parameterisations.
#                     Vehicle short-stopping: Found 0 (0.0 %) parameterisations.
#                     Pedestrian hesitation in deceleration scenario: Found 771 (77.1 %) parameterisations.
#                     Pedestrian starting before vehicle at full stop: Found 1000 (100.0 %) parameterisations.
#             Secondary criteria:
#                     Pedestrian hesitation in constant-speed scenario: Found 10 (1.0 %) parameterisations.
#             All main criteria met: Found 0 (0.0 %) parameterisations.
#             Max no of main criteria met was 2, for 771 parameterisations.
#                     Out of these, the max number of secondary criteria met was 1, for 10 parameterisations.
#             NaNs in main crit: [0 0 0 0]; sec crit: [0]
#
#     Loading parameter search from file "/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_oVA.pkl"...
#             Done.
#     Analysing model oVA, 5 parameterisations...
#             Main criteria:
#                     Vehicle asserting priority: Found 0 (0.0 %) parameterisations.
#                     Vehicle short-stopping: Found 0 (0.0 %) parameterisations.
#                     Pedestrian hesitation in deceleration scenario: Found 3 (60.0 %) parameterisations.
#                     Pedestrian starting before vehicle at full stop: Found 5 (100.0 %) parameterisations.
#             Secondary criteria:
#                     Pedestrian hesitation in constant-speed scenario: Found 0 (0.0 %) parameterisations.
#             All main criteria met: Found 0 (0.0 %) parameterisations.
#             Max no of main criteria met was 2, for 3 parameterisations.
#                     Out of these, the max number of secondary criteria met was 0, for 3 parameterisations.
#             NaNs in main crit: [0 0 0 0]; sec crit: [0]
#
#     Loading parameter search from file "/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_oVAaoVAl.pkl"...
#             Done.
#     Analysing model oVAaoVAl, 35 parameterisations...
#             Main criteria:
#                     Vehicle asserting priority: Found 0 (0.0 %) parameterisations.
#                     Vehicle short-stopping: Found 0 (0.0 %) parameterisations.
#                     Pedestrian hesitation in deceleration scenario: Found 33 (94.3 %) parameterisations.
#                     Pedestrian starting before vehicle at full stop: Found 20 (57.1 %) parameterisations.
#             Secondary criteria:
#                     Pedestrian hesitation in constant-speed scenario: Found 0 (0.0 %) parameterisations.
#             All main criteria met: Found 0 (0.0 %) parameterisations.
#             Max no of main criteria met was 2, for 18 parameterisations.
#                     Out of these, the max number of secondary criteria met was 0, for 18 parameterisations.
#             NaNs in main crit: [0 0 0 0]; sec crit: [0]
#
#     Loading parameter search from file "/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_oVAaoVAloBEvoAI.pkl"...
#             Done.
#     Analysing model oVAaoVAloBEvoAI, 350 parameterisations...
#             Main criteria:
#                     Vehicle asserting priority: Found 0 (0.0 %) parameterisations.
#                     Vehicle short-stopping: Found 0 (0.0 %) parameterisations.
#     do_2_analyse_deterministic_fits.py:101: RuntimeWarning: invalid value encountered in less
#       crit_met_all = ped_av_speed < HESITATION_SPEED_FRACT * PED_FREE_SPEED
#                     Pedestrian hesitation in deceleration scenario: Found 43 (12.3 %) parameterisations.
#     do_2_analyse_deterministic_fits.py:106: RuntimeWarning: invalid value encountered in greater
#       crit_met_all = veh_speed_at_ped_start > VEH_SPEED_AT_PED_START_THRESH
#                     Pedestrian starting before vehicle at full stop: Found 316 (90.3 %) parameterisations.
#             Secondary criteria:
#                     Pedestrian hesitation in constant-speed scenario: Found 0 (0.0 %) parameterisations.
#             All main criteria met: Found 0 (0.0 %) parameterisations.
#             Max no of main criteria met was 2, for 42 parameterisations.
#                     Out of these, the max number of secondary criteria met was 0, for 42 parameterisations.
#             NaNs in main crit: [0 0 0 0]; sec crit: [0]
#
#     Loading parameter search from file "/home/home01/tragma/COMMOTIONSFramework/SCPaper/results/DetFit_oVAoBEvoAI.pkl"...
#             Done.
#     Analysing model oVAoBEvoAI, 50 parameterisations...
#             Main criteria:
#                     Vehicle asserting priority: Found 1 (2.0 %) parameterisations.
#                     Vehicle short-stopping: Found 24 (48.0 %) parameterisations.
#                     Pedestrian hesitation in deceleration scenario: Found 28 (56.0 %) parameterisations.
#                     Pedestrian starting before vehicle at full stop: Found 39 (78.0 %) parameterisations.
#             Secondary criteria:
#                     Pedestrian hesitation in constant-speed scenario: Found 0 (0.0 %) parameterisations.
#             All main criteria met: Found 1 (2.0 %) parameterisations.
#             Max no of main criteria met was 4, for 1 parameterisations.
#                     Out of these, the max number of secondary criteria met was 0, for 1 parameterisations.
#             NaNs in main crit: [0 0 0 0]; sec crit: [0]
#
#
#     *** Retained models ***
#
#     Model oVAoBEvoAI
#     Retaining 8 out of 50 (16.0 %) parameterisations, across:
#     ('T_delta', 'beta_V')
