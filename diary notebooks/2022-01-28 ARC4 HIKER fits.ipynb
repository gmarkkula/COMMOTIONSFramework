# %% [markdown]
# # 2022-01-28 ARC4 HIKER fits
#
# Results below are from:
#
# * An ARC4 run using this release: https://github.com/gmarkkula/COMMOTIONSFramework/releases/tag/v0.2.5.8
# * And analysis code from commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/91cca1bbaa57e40a53f1c16a535beec4c058c461
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# For this first ARC4 run of the HIKER fits, I limited the number of combined parameterisations to test per model to 500. This generated a total of 5,827 model parameterisations to test, which in total took 28 h 38 min, or 103,800 s, or 18 s per parameterisation on average, in line with an approximate 10x speedup compared to the runtimes I noted in 2022-01-14.
#
# The problem noted in the 2022-01-14 diary notes, of getting stuck and not crossing, remains. This is presumably related to the observations of pedestrians getting stuck in the 2022-01-27 notes, and I think my thoughts on how to fix that there (modifying the criteria for retaining deterministic parameterisations) apply here also.
#
# Below I am only plotting parameterisations with 60 or less non-crossing trials in total across the 24x6=144 trials that each parameterisation is tested on. So it's a quite low bar, and still only relatively few parameterisations pass it, as can be seen below. (If including all parameterisations the results look similar, but the CDFs get squashed to end at a <1 value.)

# %%
# %run ../SCPaper/do_12_analyse_HIKER_fits
# Out:
# NB: Excluding parameterisations with more than 60 non-crossing trials.
#
# ...
