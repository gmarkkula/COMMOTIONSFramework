# %% [markdown]
# # 2022-01-19c Small test of combined fits before going back to ARC4
#
# Results below are for commit: ###
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# I have now:
# * Added a single dummy probabilistic simulation run at the start of `do_8_combined_fitting.py`, as discussed in the 2022-01-19 diary notes.
# * Modifed the random subsampling of combined fits to not only subsample the deterministic fits, but rather first generate the full matrix of combined deterministic $\times$ probabilstic fits, and then draw a random subset from that matrix if exceeding a max number of parameterisations.
#
# Below are results from running this with a max of 10 parameterisations per combined model. The subsampling seems to be working, and the results seem to be in line with what I have been getting before.
#
# The `oVAa` models take about 30 s per parameterisation as previously noted, but the `oVA` models are (also as previously noted) slower, and take about 60 s per parameterisation. Therefore I think 10,000 parameterisation is a sensible maximum to go for on ARC4, assuming that I can get the 10x speedups I seem to be getting in the latest testd - the longest `oVA` runs will then take 60,000 s $\approx$ 17 h each. Further below is the output from running `do_8...` again, with `overwrite_existing=False` - to be analysed later to estimate total runtime on ARC4 and appropriate ways of maybe splitting up the runs across multiple ARC4 jobs.

# %%
# %run ../SCPaper/do_9_analyse_combined_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEooBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEooBEvoAIoEAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEooBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEooBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEooBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoVAloBEooBEvoAIoEAoSNc.pkl', 
# ...

# %% [markdown]
# Output from a rerun of `do_8...` with `overwrite_existing=False`, just to see the number of parameterisations:
#
#     Fitting model oVAaoVAloBEooBEvoAIoEAoSNc across 5000 x 55 --> 275000 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAaoVAloBEooBEvoAIoEAoSNc.pkl already exists, not running parameter search for oVAaoVAloBEooBEvoAIoEAoSNc.
#     Fitting model oVAaoVAloBEooBEvoAIoEAoSNcoPF across 5000 x 16 --> 80000 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAaoVAloBEooBEvoAIoEAoSNcoPF.pkl already exists, not running parameter search for oVAaoVAloBEooBEvoAIoEAoSNcoPF.
#     Fitting model oVAaoVAloBEooBEvoAIoEAoSNv across 5000 x 317 --> 1585000 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAaoVAloBEooBEvoAIoEAoSNv.pkl already exists, not running parameter search for oVAaoVAloBEooBEvoAIoEAoSNv.
#     Fitting model oVAaoVAloBEooBEvoAIoEAoSNvoPF across 5000 x 307 --> 1535000 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAaoVAloBEooBEvoAIoEAoSNvoPF.pkl already exists, not running parameter search for oVAaoVAloBEooBEvoAIoEAoSNvoPF.
#     Fitting model oVAaoVAloBEooBEvoAIoSNv across 5000 x 3 --> 15000 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAaoVAloBEooBEvoAIoSNv.pkl already exists, not running parameter search for oVAaoVAloBEooBEvoAIoSNv.
#     Fitting model oVAaoVAloBEvoAIoEAoSNc across 46 x 55 --> 2530 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAaoVAloBEvoAIoEAoSNc.pkl already exists, not running parameter search for oVAaoVAloBEvoAIoEAoSNc.
#     Fitting model oVAaoVAloBEvoAIoEAoSNcoPF across 46 x 16 --> 736 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAaoVAloBEvoAIoEAoSNcoPF.pkl already exists, not running parameter search for oVAaoVAloBEvoAIoEAoSNcoPF.
#     Fitting model oVAaoVAloBEvoAIoEAoSNv across 46 x 317 --> 14582 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAaoVAloBEvoAIoEAoSNv.pkl already exists, not running parameter search for oVAaoVAloBEvoAIoEAoSNv.
#     Fitting model oVAaoVAloBEvoAIoEAoSNvoPF across 46 x 307 --> 14122 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAaoVAloBEvoAIoEAoSNvoPF.pkl already exists, not running parameter search for oVAaoVAloBEvoAIoEAoSNvoPF.
#     Fitting model oVAaoVAloBEvoAIoSNv across 46 x 3 --> 138 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAaoVAloBEvoAIoSNv.pkl already exists, not running parameter search for oVAaoVAloBEvoAIoSNv.
#     Fitting model oVAoVAloBEooBEvoAIoEAoSNc across 50029 x 55 --> 2751595 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAoVAloBEooBEvoAIoEAoSNc.pkl already exists, not running parameter search for oVAoVAloBEooBEvoAIoEAoSNc.
#     Fitting model oVAoVAloBEooBEvoAIoEAoSNcoPF across 50029 x 16 --> 800464 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAoVAloBEooBEvoAIoEAoSNcoPF.pkl already exists, not running parameter search for oVAoVAloBEooBEvoAIoEAoSNcoPF.
#     Fitting model oVAoVAloBEooBEvoAIoEAoSNv across 50029 x 317 --> 15859193 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAoVAloBEooBEvoAIoEAoSNv.pkl already exists, not running parameter search for oVAoVAloBEooBEvoAIoEAoSNv.
#     Fitting model oVAoVAloBEooBEvoAIoEAoSNvoPF across 50029 x 307 --> 15358903 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAoVAloBEooBEvoAIoEAoSNvoPF.pkl already exists, not running parameter search for oVAoVAloBEooBEvoAIoEAoSNvoPF.
#     Fitting model oVAoVAloBEooBEvoAIoSNv across 50029 x 3 --> 150087 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAoVAloBEooBEvoAIoSNv.pkl already exists, not running parameter search for oVAoVAloBEooBEvoAIoSNv.
#     Fitting model oVAoVAloBEvoAIoEAoSNc across 454 x 55 --> 24970 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAoVAloBEvoAIoEAoSNc.pkl already exists, not running parameter search for oVAoVAloBEvoAIoEAoSNc.
#     Fitting model oVAoVAloBEvoAIoEAoSNcoPF across 454 x 16 --> 7264 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAoVAloBEvoAIoEAoSNcoPF.pkl already exists, not running parameter search for oVAoVAloBEvoAIoEAoSNcoPF.
#     Fitting model oVAoVAloBEvoAIoEAoSNv across 454 x 317 --> 143918 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAoVAloBEvoAIoEAoSNv.pkl already exists, not running parameter search for oVAoVAloBEvoAIoEAoSNv.
#     Fitting model oVAoVAloBEvoAIoEAoSNvoPF across 454 x 307 --> 139378 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAoVAloBEvoAIoEAoSNvoPF.pkl already exists, not running parameter search for oVAoVAloBEvoAIoEAoSNvoPF.
#     Fitting model oVAoVAloBEvoAIoSNv across 454 x 3 --> 1362 combined parameterisations...
#     Output file C:\GITHUB\COMMOTIONSFramework\SCPaper/results/CombFit_oVAoVAloBEvoAIoSNv.pkl already exists, not running parameter search for oVAoVAloBEvoAIoSNv.
