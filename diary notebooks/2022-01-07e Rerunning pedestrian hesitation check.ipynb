# %% [markdown]
# # 2022-01-07e Rerunning pedestrian hesitation check
#
# Results below are for commit: ### (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Running `do_7_check_hesitation.py` on the probabilistic fitting results reported in 2022-01-07d, getting the results below, which support the same conclusions as the last time I did this, 2021-12-18. So all good here, on to combined fits.
#
#     Starting pool of workers...
#     Model oVAoEAoAN; ('T', 'DeltaV_th_rel', 'sigma_V'):
#             {'T': 0.5, 'DeltaV_th_rel': 0.0031622776601683794, 'sigma_V': 0.005623413251903491}...
#                     TTCA = -3 s: Av: 1.184 m/s; CI: [1.121, 1.247] m/s
#                     TTCA = 8 s: Av: 1.238 m/s; CI: [1.184, 1.292] m/s
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 0.983 m/s; CI: [0.898, 1.068] m/s
#                     TTCA = 8 s: Av: 1.097 m/s; CI: [1.044, 1.150] m/s
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.001, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.226 m/s; CI: [1.116, 1.337] m/s
#                     TTCA = 8 s: Av: 1.190 m/s; CI: [1.103, 1.277] m/s
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.0031622776601683794, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.099 m/s; CI: [1.010, 1.187] m/s
#                     TTCA = 8 s: Av: 1.124 m/s; CI: [1.055, 1.194] m/s
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.0031622776601683794, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.123 m/s; CI: [1.021, 1.225] m/s
#                     TTCA = 8 s: Av: 1.191 m/s; CI: [1.099, 1.282] m/s
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.01, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.153 m/s; CI: [1.042, 1.264] m/s
#                     TTCA = 8 s: Av: 1.196 m/s; CI: [1.112, 1.280] m/s
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.1, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.214 m/s; CI: [1.138, 1.290] m/s
#                     TTCA = 8 s: Av: 1.316 m/s; CI: [1.242, 1.390] m/s
#             {'T': 0.334370152488211, 'DeltaV_th_rel': 0.1, 'sigma_V': 0.03162277660168379}...
#                     TTCA = -3 s: Av: 1.483 m/s; CI: [1.380, 1.586] m/s
#                     TTCA = 8 s: Av: nan m/s; CI: [nan, nan] m/s
#             {'T': 0.334370152488211, 'DeltaV_th_rel': 0.0031622776601683794, 'sigma_V': 0.1778279410038923}...
#                     TTCA = -3 s: Av: 1.862 m/s; CI: [1.637, 2.087] m/s
#                     TTCA = 8 s: Av: 1.746 m/s; CI: [1.534, 1.958] m/s
#     Model oVAoEAoSNc; ('T', 'DeltaV_th_rel', 'tau_d'):
#             {'T': 0.1, 'DeltaV_th_rel': 0.01, 'tau_d': 499.99999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.769 m/s; CI: [0.636, 0.901] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.01, 'tau_d': 499.99999999999994}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.596 m/s; CI: [0.469, 0.723] m/s
#                             Passed.
#     Model oVAoEAoSNv; ('T', 'DeltaV_th_rel', 'tau_theta'):
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.935 m/s; CI: [0.843, 1.026] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.994 m/s; CI: [0.900, 1.087] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.954 m/s; CI: [0.871, 1.036] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.976 m/s; CI: [0.880, 1.072] m/s
#                             Passed.
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.658 m/s; CI: [0.553, 0.762] m/s
#                             Passed.
#             {'T': 0.334370152488211, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.506 m/s; CI: [0.410, 0.603] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.564 m/s; CI: [0.458, 0.670] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.440 m/s; CI: [0.363, 0.518] m/s
#                             Passed.
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.376 m/s; CI: [0.322, 0.430] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.154 m/s; CI: [1.093, 1.215] m/s
#                             Passed.
#             {'T': 0.334370152488211, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.107 m/s; CI: [1.021, 1.192] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.888 m/s; CI: [0.773, 1.002] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.670 m/s; CI: [0.551, 0.789] m/s
#                             Passed.
#     Model oVAoEAoSNvoPF; ('T', 'DeltaV_th_rel', 'tau_theta'):
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.02811706625951745}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.164 m/s; CI: [1.105, 1.223] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.039 m/s; CI: [0.953, 1.124] m/s
#                             Passed.
#             {'T': 0.334370152488211, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.040 m/s; CI: [0.933, 1.147] m/s
#                             Passed.
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.761 m/s; CI: [0.630, 0.892] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.093 m/s; CI: [1.020, 1.166] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.104 m/s; CI: [1.010, 1.198] m/s
#                             Passed.
#             {'T': 0.22360679774997896, 'DeltaV_th_rel': 0.001, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.156 m/s; CI: [1.078, 1.234] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.104 m/s; CI: [1.023, 1.184] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.0031622776601683794, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.078 m/s; CI: [0.994, 1.162] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.01, 'tau_theta': 0.8891397050194613}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.833 m/s; CI: [0.711, 0.954] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.001, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.143 m/s; CI: [1.079, 1.208] m/s
#                             Passed.
#             {'T': 0.1, 'DeltaV_th_rel': 0.01, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.301] m/s
#                     TTCA = 8 s: Av: 1.008 m/s; CI: [0.902, 1.113] m/s
#                             Passed.
#             {'T': 0.14953487812212204, 'DeltaV_th_rel': 0.01, 'tau_theta': 5.000000000000001}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 0.869 m/s; CI: [0.750, 0.989] m/s
#                             Passed.
#     Model oVAoSNv; ('tau_theta',):
#             {'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.300 m/s; CI: [1.300, 1.300] m/s
#                     TTCA = 8 s: Av: 1.165 m/s; CI: [1.128, 1.203] m/s
#                             Passed.
#     Model oVAoSNvoPF; ('tau_theta',):
#             {'tau_theta': 0.15811388300841894}...
#                     TTCA = -3 s: Av: 1.299 m/s; CI: [1.299, 1.300] m/s
#                     TTCA = 8 s: Av: 1.121 m/s; CI: [1.050, 1.193] m/s
#                             Passed.
