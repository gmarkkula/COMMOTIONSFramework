# %% [markdown]
# # 2022-01-07d Medium-scale probabilistic fits again, with adjusted noise magnitude search ranges
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/458bb3da03f85668c1089dda2e3e536580b8f444 (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Based on the 2022-01-07c notes, I have:
# * Reduced $c_\tau$ (the factor by which noise magnitudes $\tau_*$ are multiplied if `oPF` is not enabled) from 0.01 to 0.001.
# * Shifted the search ranges for $\tau_d$ and $\tau_\theta$ up by a corresponding factor 10.
# * Extended the upper edge of the $\sigma_V$ search range by another factor 10.
#
# The parameter grid is now defined as:
#
#     N_VALS_PER_PARAM = 5
#     PARAM_ARRAYS = {}
#     PARAM_ARRAYS['T'] = np.logspace(np.log10(0.1), np.log10(0.5), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['DeltaV_th_rel'] = np.logspace(np.log10(0.001), np.log10(0.1), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['sigma_V'] = np.logspace(np.log10(0.001), np.log10(1), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['tau_theta'] = np.logspace(np.log10(0.005), np.log10(5), N_VALS_PER_PARAM)
#     PARAM_ARRAYS['tau_d'] = np.logspace(np.log10(0.5), np.log10(500), N_VALS_PER_PARAM)
#
# All is looking pretty good below. The $\tau_d$ is still touching upper bound for `oVAoEAoSNc`, but given the rest of the results I am pretty happy like this. On to medium-scale combined fits!

# %%
# %run ../SCPaper/do_6_analyse_probabilistic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNvoPF.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\ProbFit_oVAoAN.pkl"...
# 	Done.
# Analysing model oVAoAN, 5 parameterisations...
# 		Collision-free encounter: Found 5 (100.0 %) parameterisations.
# ...
