# %% [markdown]
# # 2021-12-19 First combined fits
#
# Results below are for commit: ### (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# I have now created two new scripts:
# * `do_6_combined_fitting.py`, which combines retained model parameterisations from the deterministic fits with retained model parameterisations from the probabilistic fits, and tests it on the same criteria as applied in the probabilistic fits. I am excluding the `oVAoEAoAN` model from the probabilistic models, because of the results reported in yesterday's diary notes. And for this first test I am only including the `oVAoBEvoAI` parameterisations from the deterministic fits.
# * `do_7_analyse_combined_fits.py`, which reruns the `do_4...` analysis but on these combined fits.
#
# We can see from the results below that all of the combined models tested here pass the probabilistic criteria, which is nice. In some cases, especially with the `oPF` assumption, quite a few parameterisations are excluded, due to not passing the pedestrian hesitation criterion. I suspect that the main reason for this is not the inclusion of the `oBEvoAI` assumptions, but rather that there was some randomness already from the start to exactly which `oPF` parameterisations passed the pedestrian hesitation criterion (hesitation is weaker and/or rarer), so testing it again now will naturally tend to exclude further parameterisations.

# %%
# %run ../SCPaper/do_7_analyse_combined_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoBEvoAIoSNvoPF.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\CombFit_oVAoBEvoAIoEAoSNc.pkl"...
# 	Done.
# Analysing model oVAoBEvoAIoEAoSNc, 14 parameterisations...
# 		Collision-free encounter: Found 14 (100.0 %) parameterisations.
# 		Collision-free encounter with pedestrian priority: Found 14 (100.0 %) parameterisations.
# 		Collision-free pedestrian lead situation: Found 14 (100.0 %) parameterisations.
# 		Pedestrian hesitation in constant-speed scenario: Found 8 (57.1 %) parameterisations.
# 	All criteria met: Found 8 (57.1 %) parameterisations.
# ...
