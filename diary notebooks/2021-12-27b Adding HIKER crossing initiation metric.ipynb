# %% [markdown]
# # 2021-12-27b Adding HIKER crossing initiation metric
#
# Results below are for commit: ### (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# I have now added `sc_fitting.metric_hiker_cit()`, returning the time at which the pedestrian first starts moving, relative to the time at which the (emulated) first vehicle passed the pedestrian. Returning NaN if the pedestrian doesn't move at all, or the (emulated "second") vehicle enters the conflict space before the pedestrian.
#
# Below just verifying that it works as expected for the same `oVAoBEvoAI` model as in the earlier diary notes from today - which it does.
#
# (NB running the below with laptop not plugged in => slower simulation run times.)

# %%
# %run ../SCPaper/test_scpaper_scenario.py
# Out:
# *** Looping through dict_keys(['25_2', '25_2_y', '25_3', '25_3_y', '25_4', '25_4_y', '25_5', '25_5_y', '30_2', '30_2_y', '30_3', '30_3_y', '30_4', '30_4_y', '30_5', '30_5_y', '35_2', '35_2_y', '35_3', '35_3_y', '35_4', '35_4_y', '35_5', '35_5_y']):
#
# 25_2 variation 1/1:
# Initialising and running simulation took 2.728 s.
# Metric 25_2_hiker_cit = nan
#
# 25_2_y variation 1/1:
# Initialising and running simulation took 4.693 s.
# Metric 25_2_y_hiker_cit = 4.65
#
# 25_3 variation 1/1:
# Initialising and running simulation took 3.102 s.
# Metric 25_3_hiker_cit = nan
#
# 25_3_y variation 1/1:
# Initialising and running simulation took 5.332 s.
# Metric 25_3_y_hiker_cit = 5.65
#
# 25_4 variation 1/1:
# Initialising and running simulation took 2.022 s.
# Metric 25_4_hiker_cit = 0.025000000000000355
#
# 25_4_y variation 1/1:
# Initialising and running simulation took 2.102 s.
# Metric 25_4_y_hiker_cit = 0.025000000000000355
#
# 25_5 variation 1/1:
# ...
