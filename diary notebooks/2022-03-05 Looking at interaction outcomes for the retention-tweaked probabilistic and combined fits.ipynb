# %% [markdown]
# # 2022-03-05 Looking at interaction outcomes for the retention-tweaked probabilistic and combined fits
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/6b69117c93db04b38b6fa5bea59acd204ca59e66
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# I just realised that I didn't include the interaction outcome plots for the probabilistic and combined fits in the 2022-02-03 diary notes, so I am showing those plots below. All looks sensible.

# %%
# %run ../SCPaper/do_6_analyse_probabilistic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNvoPF.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\ProbFit_oVAoAN.pkl"...
# 	Done.
# Analysing model oVAoAN, 10 parameterisations...
# 		Collision-free encounter: Found 10 (100.0 %) parameterisations.
# ...

# %%
# %run ../SCPaper/do_9_analyse_combined_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEooBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEooBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEooBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEooBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoBEooBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoBEooBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoBEooBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\
# ...
