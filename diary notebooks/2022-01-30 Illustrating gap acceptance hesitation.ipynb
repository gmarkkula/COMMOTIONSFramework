# %% [markdown]
# # 2022-01-30 Illustrating gap acceptance hesitation
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/340f61ce74fadc8e98d7629950bf6c637cc623c8
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# A first go at illustrating the difference between value/accumulator noise vs sensory noise, here for models `oVAoEAoAN` and `oVAoEAoSNvoPF`. Quite nice, but a tendency of the latter model to get stuck becomes obvious; both stuck standing after the car has passed, and stuck at a high speed. I think this is to a large part due to the evidence accumulation. Changing the selection/retention criteria to avoid parameterisations with a too large tendency to get stuck standing would probably help improve this. To solve it more completely some tweaks to the model formulation may be needed, at the level of the value squashing (in line with what Yi-Shin has done), and/or at the level of the accumulator (e.g., generalising beyond low-pass filtering to other accumulation schemes).

# %%
# %run ../SCPaper/do_fig_probabilistic_hesitation.py
# Out:
# Loading "C:\GITHUB\COMMOTIONSFramework\SCPaper/results/RetainedProbModels.pkl"...
# 	Done.
# Loading "C:\GITHUB\COMMOTIONSFramework\SCPaper/results/fig_ProbHesitationSimResults.pkl"...
# 	Done.
