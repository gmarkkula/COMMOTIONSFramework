# %% [markdown]
# # 2021-12-11 New probabilistic fitting test after adjusting the hesitation metric
#
# Results below are for commit: ### (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# After looking more closely at the simulations of the `PedHesitateVehConst` scenario with the noisy models, I realised that one reason the models might be showing limited hesitation is that I am only looking from the start of the simulation to halfway to the conflict space, and quite often the hesitation deceleration instead seems to be coming just as the pedestrian is getting close to its safety distance from the conflict space. Therefore I now instead measure average speed all the way up until conflict space entry.
#
# With this update, I now find parameterisations that meet all four criteria for: `oVAoAN`, `oVAoEAoAN`, `oVAoEAoSNc`, `oVAoEAoSNv`, `oVAoEAoSNvoPF`, and `oVAoSNv`.
#
# Next, I need to look closer at the `oAN` models, as mentioned in the 2021-12-09 notes.

# %%
# %run ../SCPaper/do_4_analyse_probabilistic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNvoPF.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\ProbFit_oVAoAN.pkl"...
# 	Done.
# Analysing model oVAoAN, 3 parameterisations...
# 		Collision-free encounter: Found 3 (100.0 %) parameterisations.
# ...
