# %% [markdown]
# # 2022-01-14 New HIKER medium-scale results
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/574ac4f4d6f839b8a2f35232d6c5c5fd690db90e
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Below are the HIKER predictions for the most recent medium-scale combined fits. Aligns with past HIKER test results (2022-01-02, 2022-01-11) - the `oVAa` model predictions seem pretty poor, non-`oEA` predictions are early, `oEA` without `oPF` is late, but the `oEAoPF` combination looks quite nice. More of a tendency here than in the 2022-01-02 results to get stuck and not cross though - may be because of the small subset of deterministic fits included. It will also be interesting to see what this looks like for the model also including `oBEo`.
#
# On my computer, these tests are taking about 1.5-3 min per parameterisation, depending on whether the model tends to cross early or late.

# %%
# %run ../SCPaper/do_12_analyse_HIKER_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoVAloBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoVAloBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoVAloBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoVAloBEvoAIoSNv.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\HIKERFit_oVAaoVAloBEvoAIoEAoSNv.pkl"...
# 	Done.
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\HIKERFit_oVAaoVAloBEvoAIoSNv.pkl"...
# 	Done.
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\HIKERFit_oVAoVAloBEvoAIoEAoSNc.pkl"...
# 	Done.
# ...
