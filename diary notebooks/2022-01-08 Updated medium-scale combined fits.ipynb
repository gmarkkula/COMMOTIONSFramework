# %% [markdown]
# # 2022-01-08 Updated medium-scale combined fits
#
# Results below are for commit: ### (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# I have now run the combined fits for the retained parameterisations for `oVAaoVAloBEvoAI` shown in the 2022-01-05 notes, combined with the retained parameterisations for the probabilistic models shown in the 2022-01-07d notes.
#
# The results below are now not looking quite as good as they did for the `oVA` models I think (cf. the 2021-12-19 notes) - lots more colliding, and less pedestrian hesitation. The collision-proneness is something I have seen previously with the `oVAa` models, and I haven't checked for it earlier in the pipeline, so in a sense it's natural that it shows up here to get weeded out. Hopefully the retained parameterisations are not too collision-prone if tested in larger scale and/or in other kinematic scenarios.
#
# With regards to the limited pedestrian hesitation I don't know if the kinematic scenario in question now happens to be badly chosen for these models - as can be seen below (for `oVAaoVAloBEvoAIoEAoSNvoPF`, and even more clearly for `oVAaoVAloBEvoAIoEAoSNc`) there is a tendency to accelerate to pass first instead. Or whether they are just less prone to hesitate in general.
#
# I will press on anyway and look at the rest of the pipeline also for these models...

# %%
# %run ../SCPaper/do_9_analyse_combined_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoSNvoPF.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\CombFit_oVAaoVAloBEvoAIoEAoSNc.pkl"...
# 	Done.
# Analysing model oVAaoVAloBEvoAIoEAoSNc, 76 parameterisations...
# 		Collision-free encounter: Found 62 (81.6 %) parameterisations.
# 		Collision-free encounter with pedestrian priority: Found 72 (94.7 %) parameterisations.
# 		Collision-free pedestrian lead situation: Found 76 (100.0 %) parameterisations.
# 		Pedestrian hesitation in constant-speed scenario: Found 0 (0.0 %) parameterisations.
# ...
