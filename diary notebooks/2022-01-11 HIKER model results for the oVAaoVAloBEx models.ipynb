# %% [markdown]
# # 2022-01-11 HIKER model results for the oVAaoVAloBE* models
#
# Results below are for commit: ### (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Finishing off the "full pipeline" tests I have been running with also looking at the HIKER scenario predictions for the `oVAaoVAloBE*` models. The results are qualitatively similar to the previous (2022-01-02) results for the `oVAoBE*` models (also shown below), in that models with `oEA` but without `oPF` always cross after the vehicle, and models without it always before - but in this case no `oEAoPF` model was retained from the combined fitting, so we it's not clear whether the predictions for that type of model would be as promising-looking as the ones for the `oVAoBE*oEAoPF` model below. One not so promising aspect of the `oVAaoVAloBE*oEA` model just below though is that it is very slow in beginning to cross after the car has passed - possibly due to the quite high $\Delta V_{th}$ values retained in the combined fits (2022-01-02 notes)?

# %%
# %run ../SCPaper/do_12_analyse_HIKER_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAaoVAloBEvoAIoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEvoAIoSNvoPF.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\HIKERFit_oVAaoVAloBEvoAIoEAoSNv.pkl"...
# 	Done.
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\HIKERFit_oVAaoVAloBEvoAIoSNv.pkl"...
# 	Done.
# ...
