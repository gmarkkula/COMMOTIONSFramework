# %% [markdown]
# # 2022-01-13c Another round of medium-scale combined fits
#
# Results below are for commit: ###
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# I have now added functionality to `do_8_combined_fitting.py` for drawing a random subset of retained deterministic parameterisations from which to build combined parameterisations. In the test run below I am limiting the number of deterministic parameterisations to 10.
#
# The results for these new combined fits align with what I have seen before for the `oVA` models (2021-12-19) and the `oVAa` models (2022-01-08), the former look nicer in that they collide less and exhibit pedestrian hesitation much more consistently.

# %%
# %run ../SCPaper/do_9_analyse_combined_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAaoVAloBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoVAloBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoVAloBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoVAloBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\CombFit_oVAoVAloBEvoAIoSNv.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\CombFit_oVAaoVAloBEvoAIoEAoSNc.pkl"...
# 	Done.
# Analysing model oVAaoVAloBEvoAIoEAoSNc, 10 parameterisations...
# 		Collision-free encounter: Found 9 (90.0 %) parameterisations.
# ...
