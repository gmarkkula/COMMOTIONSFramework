# %% [markdown]
# # 2021-12-15b Same probabilistic fits again, after some minor changes
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/66d2d0a24c9542d7609fbefa2825e8a5fba19532 (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Rerunning the same probabilistic fits as earlier today, after:
# * Changing the $T_\delta$ parameter for these `oVA` fits to 60 s, since that was the value that was retained from the deterministic fits for the `oVAoBEvoAI` model.
# * Changing the `oPF` Kalman prior on the other agent's speed from 0.5 to 2 times the other agent's free speed. This was based on some separate testing indicating that this larger multiplier made the `oPF` model capable of exhibiting pedestrian hesitation - as can be seen in the results below.
#
# Overall my feeling is that the `oPF` assumption does introduce two or more quite important parameters, $\sigma_\dot{x}$ and the priors, which I am currently trying to treat as fixed parameters, but I am not sure that makes sense. So since the simpler models without `oPF` are meeting the criteria so far, I am considering excluding the `oPF` models from further analysis.
#
# I have also decided not to try to make any low-level changes in the model to get at the natural deceleration tendency in the `oAN` model. It isn't entirely trivial to address the "negative accelerations in buffer" issue that I think is causing it, and it is also not 100% clear that fixing it would be the right thing to do from a model/theory perspective. I will instead do a separate analysis on the retained `oAN` parameterisations.
#
# Suitable next steps:
# * The follow-up analysis on the retained `oAN` models mentioned just above (a script `do_5...`?).
# * Updates to `sc_fitting.SCPaperParameterSearch` and a new script (`do_6...`?) to test all retained deterministic model parameterisations combined with all retained probabilistic model parameterisations, on the probablistic criteria.

# %%
# %run ../SCPaper/do_4_analyse_probabilistic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNvoPF.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\ProbFit_oVAoAN.pkl"...
# 	Done.
# Analysing model oVAoAN, 5 parameterisations...
# 		Collision-free encounter: Found 5 (100.0 %) parameterisations.
# ...
