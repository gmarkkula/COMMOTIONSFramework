# %% [markdown]
# # 2022-01-02 Same HIKER model results again, after tweaking the "first vehicle" emulation
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/83ccb0eefce7e8c67856f257e54d625c0604a1d3 (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Based on what I wrote in yesterday's notes, I have now tweaked the emulation of the "first HIKER vehicle", to instead add -Inf value if an agent's predicted value is less than the safety distance $D_s$ away from the conflict space before the "inhibition time" at which the emulated first vehicle is considered to have passed. As can be seen in the plots below, this has solved the problem observed in yesterday's notes, where `oPF` models could sometimes exhibit large negative crossing times. Just like the previous implementation of the "first vehicle" emulation, also this new one is incapable of having the model exhibit small negative crossing times, as was sometimes seen in the HIKER study. One could work further on the implementation of the first vehicle emulation to go in that direction (e.g., by subtracting $\Delta T$ or some free parameter from the inhibition time when doing the value calculation), but I am not sure that would really be worth the effort, given that I think the argument around these CITs will mostly be qualitative anyway.
#
# The other todo items noted yesterday, about increasing the range of noise magnitude in the probabilistic fittings, still stand.
#
# I think this is a good enough first full version of the HIKER stuff. Time to return to the rest of the pipeline and (hopefully) start finishing things off.
#
# ## Empirical CITs

# %%
# %run ../SCPaper/do_8_get_empirical_HIKER_CITs.py
# Out:
# Saving HIKER CIT data...

# %% [markdown]
# ## Model CITs

# %%
# %run ../SCPaper/do_10_analyse_HIKER_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEvoAIoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEvoAIoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEvoAIoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEvoAIoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\HIKERFit_oVAoBEvoAIoSNvoPF.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\HIKERFit_oVAoBEvoAIoEAoSNc.pkl"...
# 	Done.
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\HIKERFit_oVAoBEvoAIoEAoSNv.pkl"...
# 	Done.
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\HIKERFit_oVAoBEvoAIoEAoSNvoPF.pkl"...
# 	Done.
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\HIKERFit_oVAoBEvoAIoSNv.pkl"...
# 	Done.
# ...
