# %% [markdown]
# # 2021-12-10 ARC4 run of deterministic fits
#
# Results below are for commits:
# * Fitting code (`do_1_...`) cloned to ARC4: https://github.com/gmarkkula/COMMOTIONSFramework/commit/130d0de03429ad2fc2d13d9c9f34bd172a0a278c
# * Results analysis code (`do_2_...`) run below: ###
#
# (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# I have now rerun the deterministic fits on ARC4, using the base Anaconda Python environment (currently the [Anaconda 2019.10 release](https://docs.anaconda.com/anaconda/reference/release-notes/#anaconda-2019-10-october-15-2019), as documented [here](https://arcdocs.leeds.ac.uk/software/compilers/anaconda.html)), with a further expanded parameter grid:
#
#     N_GRID_SIDE = 10
#     PARAM_ARRAYS['k_c'] = np.logspace(np.log10(0.2), np.log10(2), N_GRID_SIDE)
#     PARAM_ARRAYS['k_sc'] = np.logspace(np.log10(0.02), np.log10(0.2), N_GRID_SIDE)
#     PARAM_ARRAYS['thetaDot_1'] = np.logspace(np.log10(0.005), np.log10(0.3), N_GRID_SIDE)
#     PARAM_ARRAYS['T_delta'] = np.logspace(np.log10(10), np.log10(100), N_GRID_SIDE)
#     PARAM_ARRAYS['beta_V'] = np.logspace(np.log10(1), np.log10(200), N_GRID_SIDE)
#     PARAM_ARRAYS['T_Of'] = np.logspace(np.log10(0.5), np.log10(10), N_GRID_SIDE)
#     PARAM_ARRAYS['sigma_O'] = np.logspace(np.log10(0.02), np.log10(2), N_GRID_SIDE)
#
# Basically the results below just confirm the results from 2021-12-05.
#
# One note here: Because of minor code evolution since I cloned the code to ARC4, the pickled results files are not 100% compatible with my current analysis code in `do_2_...` (more specifically I can't easily make time series plots, because of changes to at least the `SCPaperScenario` class made to support the probabilistic fits). I should watch out for this type of problem going forward.
#
# For future reference, documenting the time needed for each fit (not exact; calculating in my head from the logs; added these to new directory `SCPaper/ARC4 logs`):
#
# | Model               | Time     |
# | :--------           | :-------: |
# | **base total**      | **57 min** |
# |                     | 2 s     |
# | oBEv                | 15 s    |
# | oBEvoAI             | 17 s    |
# | oBEo                | 2 min   |
# | oBEooBEv            | 25 min  |
# | oBEooBEvoAI         | 29 min  |
# | **oVA total**       | **23 min** |
# | oVA                 | 1 s     |
# | oVAoBEv             | 7 s     |
# | oVAoBEvoAI          | 11 s    |
# | oVAoBEo             | 1 min   |
# | oVAoBEooBEv         | 9 min   |
# | oVAoBEooBEvoAI      | 13 min  |
# | **oVAa total**      | **17 min** |
# | oVAa                | < 1 s   |
# | oVAaoBEv            | 5 s     |
# | oVAaoBEvoAI         | 7 s     |
# | oVAaoBEo            | 1 min   |
# | oVAaoBEooBEv        | 7 min   |
# | oVAaoBEooBEvoAI     | 9 min   |
# | **oVAoBEc total**   | **30 min** |
# | ...can't be arsed... | :) |
# | **oVAoVAl total**   | **531 min** |
# | oVAoVAl             | 8 s     |
# | oVAoVAloBEv         | 2 min   |
# | oVAoVAloBEvoAI      | 3 min   |
# | oVAoVAloBEo         | 21 min  |
# | oVAoVAloBEooBEv     | 197 min |
# | oVAoVAloBEooBEvoAI  | 306 min |
# | **oVAaoVAl total**  | **317 min** |
# | oVAaoVAl            | 7 s     |
# | oVAaoVAloBEv        | 1 min   |
# | oVAaoVAloBEvoAI     | 2 min   |
# | oVAaoVAloBEo        | 14 min  |
# | oVAaoVAloBEooBEv    | 122 min |
# | oVAaoVAlooBEoBEvoAI | 178 min |
#
# Or a total of 975 min = 16.3 hours. Based on the tenfold speed difference I have seen between my laptop and one 40-core ARC4 node (which is what I have used here), this would have taken about seven days on my laptop.

# %%
# %run ../SCPaper/do_2_analyse_deterministic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVA.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAa.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/re
# ...
