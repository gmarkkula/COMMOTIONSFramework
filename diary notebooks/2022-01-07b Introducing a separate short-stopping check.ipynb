# %% [markdown]
# # 2022-01-07b Introducing a separate short-stopping check
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/00a03508396b3b42cd075bfcb35c783ba5bb7d0f (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# As planned in the 2022-01-05b notes, I have now added scripts for rerunning model parameterisations that have been found to achieve short-stopping in the "exaggerated early deceleration" sense, to test whether they achieve it also in the "exaggerated final stopping margin" sense discussed and tested in the 2022-01-04 notes.
#
# ## A small-scale test
#
# Running through the new `do_3_check_short_stopping.py` script with number of parameterisations per model limited to 50, as a first check. As can be seen below, this new criterion disconfirms the short-stopping previously identified for some non-affordance based model variants, as well as for the vanilla `oVA` model. Most `oVA*oBE*` models all see their short-stopping confirmed below, some lack of confirmation for some of them as well as for `oVAoVAl`, but many of those need a full-scale run to see for sure what the results are.

# %%
# %run ../SCPaper/do_4_analyse_short_stopping_check.py
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oVA.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oVAa.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oVAaoBEc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oVAaoBEcoBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oVAaoBEcoBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oVAaoBEcoBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oVAaoBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oVAaoBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_oVAaoBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\AltShortStopFit_
# ...

# %% [markdown]
# ## Expected execution time for full-scale run
#
# As can be seen at the bottom below, across all deterministic models there are 262,550 parameterisations that have been identified as exhibiting short-stopping in the early deceleration sense. In the small-scale test above, my computer managed roughly one parameterisation per second for the most advanced models, so on my computer a full-scale run would take about 73 h, i.e. I would expect roughly 7.3 h on ARC4.

# %%
# %run ../SCPaper/do_2_analyse_deterministic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVA.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAa.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEo.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEooBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEooBEvoAI.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\DetFit_oVAaoBEcoBEv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/re
# ...

# %%
idx_short_stop = CRITERIA[i_MAIN].index('Vehicle short-stopping')
n_did_short_stop = 0
for model, det_fit in det_fits.items():
    idx_did_short_stop = det_fit.main_criteria_matrix[idx_short_stop, :]
    n_did_short_stop += len(np.nonzero(idx_did_short_stop)[0])
print(f'Across all models, short-stopping was identified, in the early deceleration sense, for {n_did_short_stop} parameterisations.')
# Out:
# Across all models, short-stopping was identified, in the early deceleration sense, for 262550 parameterisations.
