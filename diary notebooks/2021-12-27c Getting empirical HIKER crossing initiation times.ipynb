# %% [markdown]
# # 2021-12-27c Getting empirical HIKER crossing initiation times
#
# Results below are for commit: https://github.com/gmarkkula/COMMOTIONSFramework/commit/7e24b07ae617caa0860829dad0e596f29da52a60 (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Reading from `hiker_cts.csv` from https://github.com/jampekka/vddfit/ to extract crossing initiation times (CITs) in all scenarios without eHMI activation. Plotting CDFs and saving a pickle.
#
# Seems like I am getting the same CDFs as seen in the Pekkanen et al. (2021) paper.
#
# One thing which becomes clearer when plotting these CDFs organised as below is that the constant-speed scenario CDFs really very much looks like the first parts of the deceleration scenario CDFs.

# %%
# %run ../SCPaper/do_8_get_empirical_HIKER_CITs.py
# Out:
# Saving HIKER CIT data...
