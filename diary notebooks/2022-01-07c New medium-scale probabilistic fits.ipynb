# %% [markdown]
# # 2022-01-07c New medium-scale probabilistic fits
#
# Results below are for commit: ### (Rerunning the code below for other commits is not likely/guaranteed to give the same results.)
#
# Rerunning the same probabilistic fits as reported in the 2021-12-15b notes, but with $T_\delta$ = 40 s as described in previous diary notes, and of course with the various other code modifications which have happened since then (all in the non-probabilistic parts of the framework though).
#
# The results below are qualitatively very similar to those obtained 2021-12-15b, so all seems pretty good here.
#
# The only thing I note is that the retained noise magnitudes ($\tau_*$) for `oPF` models are at the upper edge of the searched range, whereas for non-`oPF` models they are more appropriately centred. This suggests I should adjust both the search range up and $c_\tau$ down by the same factor. About a factor ten I think? I also seems like I could adjust the $\sigma_V$ search range upwards.

# %%
# %run ../SCPaper/do_6_analyse_probabilistic_fits
# Out:
# ['C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoAN.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoEAoSNvoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNc.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNcoPF.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNv.pkl', 'C:\\GITHUB\\COMMOTIONSFramework\\SCPaper/results\\ProbFit_oVAoSNvoPF.pkl']
#
# Loading parameter search from file "C:\GITHUB\COMMOTIONSFramework\SCPaper/results\ProbFit_oVAoAN.pkl"...
# 	Done.
# Analysing model oVAoAN, 5 parameterisations...
# 		Collision-free encounter: Found 5 (100.0 %) parameterisations.
# ...
